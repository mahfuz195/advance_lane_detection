# %%
import cv2
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import glob

# %matplotlib inline

print ('OK')
# Out:
# OK

# %%
img = mpimg.imread('camera_cal/calibration1.jpg')
image_shape = img.shape
print(image_shape)
plt.imshow(img)
# Out:
# (720, 1280, 3)

# %% [markdown]
# ### Camera Calibration

# %%
nx = 9
ny = 6

objpoints = []
imgpoints = []

objp = np.zeros((nx*ny,3), np.float32)
objp[:,:2] = np.mgrid[0:nx,0:ny].T.reshape(-1,2)

fnames = glob.glob("camera_cal/calibration*.jpg")

for fname in fnames:
    img = mpimg.imread(fname)
    gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
    ret, corners = cv2.findChessboardCorners(gray, (nx,ny), None)
    if ret:
        objpoints.append(objp)
        imgpoints.append(corners)
        
# use the object and image points to caliberate the camera and compute the camera matrix and distortion coefficients
ret, cameraMatrix, distortionCoeffs, rvecs, tvecs = cv2.calibrateCamera(objpoints, imgpoints, image_shape[:2],None,None)

print ('OK')
# Out:
# OK

# %% [markdown]
# ### Distortion Correction

# %%
img = mpimg.imread('camera_cal/calibration2.jpg')
undistorted = cv2.undistort(img, cameraMatrix, distortionCoeffs, None, cameraMatrix)
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(24, 9))
f.tight_layout()
ax1.imshow(img)
ax1.set_title('Original Image', fontsize=50)
ax2.imshow(undistorted)
ax2.set_title('Undistorted Image', fontsize=50)
plt.subplots_adjust(left=0., right=1, top=0.9, bottom=0.)

# %%
def abs_sobel_thresh(img, orient='x', thresh_min=0, thresh_max=255):
    #gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
    if orient == 'x':
        abs_sobel = np.absolute(cv2.Sobel(gray, cv2.CV_64F, 1, 0))
    if orient == 'y':
        abs_sobel = np.absolute(cv2.Sobel(gray, cv2.CV_64F, 0, 1))
    scaled_sobel = np.uint8(255*abs_sobel/np.max(abs_sobel))
    binary_output = np.zeros_like(scaled_sobel)
    binary_output[(scaled_sobel >= thresh_min) & (scaled_sobel <= thresh_max)] = 1
    return binary_output

def mag_thresh(img, sobel_kernel=5, mag_thresh=(0, 255)):
    
    gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
    # Take both Sobel x and y gradients
    sobelx = cv2.Sobel(gray, cv2.CV_64F, 1, 0, ksize=sobel_kernel)
    sobely = cv2.Sobel(gray, cv2.CV_64F, 0, 1, ksize=sobel_kernel)
    # Calculate the gradient magnitude
    gradmag = np.sqrt(sobelx**2 + sobely**2)
    # Rescale to 8 bit
    scale_factor = np.max(gradmag)/255 
    gradmag = (gradmag/scale_factor).astype(np.uint8) 
    # Create a binary image of ones where threshold is met, zeros otherwise
    binary_output = np.zeros_like(gradmag)
    binary_output[(gradmag >= mag_thresh[0]) & (gradmag <= mag_thresh[1])] = 1
    
    # Return the binary image
    return binary_output

def dir_threshold(image, sobel_kernel=5, thresh=(0, np.pi/2)):
    gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
    # Calculate the x and y gradients
    sobelx = cv2.Sobel(gray, cv2.CV_64F, 1, 0, ksize=sobel_kernel)
    sobely = cv2.Sobel(gray, cv2.CV_64F, 0, 1, ksize=sobel_kernel)
    # Take the absolute value of the gradient direction, 
    # apply a threshold, and create a binary image result
    absgraddir = np.arctan2(np.absolute(sobely), np.absolute(sobelx))
    binary_output =  np.zeros_like(absgraddir)
    binary_output[(absgraddir >= thresh[0]) & (absgraddir <= thresh[1])] = 1
    
    return binary_output

# %%
def threshold_image(img):
    img = cv2.undistort(img, cameraMatrix, distortionCoeffs, None, cameraMatrix)
    
    # convert to gray scale
    gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
    
    height, width = gray.shape
    
    # apply gradient threshold on the horizontal gradient
    sx_binary = abs_sobel_thresh(gray, 'x', 10, 200)
    
    # apply gradient direction threshold so that only edges closer to vertical are detected.
    dir_binary = dir_threshold(gray, thresh=(np.pi/6, np.pi/2))
    
    # combine the gradient and direction thresholds.
    combined_condition = ((sx_binary == 1) & (dir_binary == 1))
    
    # R & G thresholds so that yellow lanes are detected well.
    color_threshold = 150
    R = img[:,:,0]
    G = img[:,:,1]
    color_combined = np.zeros_like(R)
    r_g_condition = (R > color_threshold) & (G > color_threshold)
    
    
    # color channel thresholds
    hls = cv2.cvtColor(img, cv2.COLOR_RGB2HLS)
    S = hls[:,:,2]
    L = hls[:,:,1]
    
    # S channel performs well for detecting bright yellow and white lanes
    s_thresh = (90, 255)
    s_condition = (S > s_thresh[0]) & (S <= s_thresh[1])
    
    # We put a threshold on the L channel to avoid pixels which have shadows and as a result darker.
    l_thresh = (120, 255)
    l_condition = (L > l_thresh[0]) & (L <= l_thresh[1])

    # combine all the thresholds
    # A pixel should either be a yellowish or whiteish
    # And it should also have a gradient, as per our thresholds
    color_combined[(r_g_condition & l_condition) & (s_condition | combined_condition)] = 1
    
    # apply the region of interest mask
    mask = np.zeros_like(color_combined)
    region_of_interest_vertices = np.array([[0,height-1], [width/2, int(0.5*height)], [width-1, height-1]], dtype=np.int32)
    cv2.fillPoly(mask, [region_of_interest_vertices], 1)
    thresholded = cv2.bitwise_and(color_combined, mask)
    
    return thresholded

img = mpimg.imread('test_images/test10.jpg')
plt.imshow(img)
thresholded = threshold_image(img)

# %%
img = mpimg.imread('test_images/test10.jpg')
thresholded = threshold_image(img)
img = cv2.undistort(img, cameraMatrix, distortionCoeffs, None, cameraMatrix)
#cv2.imwrite('thresholded.jpg',thresholded)

# Plot the 2 images side by side
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(24, 9))
f.tight_layout()
ax1.imshow(img)
ax1.set_title('Original Image', fontsize=50)
ax2.imshow(thresholded, cmap='gray')
ax2.set_title('Thresholded Image', fontsize=50)
plt.subplots_adjust(left=0., right=1, top=0.9, bottom=0.)

# %%
# Vertices extracted manually for performing a perspective transform
bottom_left = [220,720]
bottom_right = [1200, 720]
top_left = [570, 470]
top_right = [780, 470]

source = np.float32([bottom_left,bottom_right,top_right,top_left])

pts = np.array([bottom_left,bottom_right,top_right,top_left], np.int32)
pts = pts.reshape((-1,1,2))
copy = img.copy()
cv2.polylines(copy,[pts],True,(255,0,0), thickness=3)

# Destination points are chosen such that straight lanes appear more or less parallel in the transformed image.
bottom_left = [320,720]
bottom_right = [920, 720]
top_left = [320, 1]
top_right = [920, 1]

dst = np.float32([bottom_left,bottom_right,top_right,top_left])
M = cv2.getPerspectiveTransform(source, dst)
M_inv = cv2.getPerspectiveTransform(dst, source)
img_size = (image_shape[1], image_shape[0])

warped = cv2.warpPerspective(thresholded, M, img_size , flags=cv2.INTER_LINEAR)
    
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(24, 9))
f.tight_layout()
ax1.imshow(copy)
ax1.set_title('Original Image', fontsize=50)
ax2.imshow(warped, cmap='gray')
ax2.set_title('Warped Image', fontsize=50)
plt.subplots_adjust(left=0., right=1, top=0.9, bottom=0.)

# %%
histogram = np.sum(warped[warped.shape[0]//2:,:], axis=0)
#plt.plot(histogram)

# Peak in the first half indicates the likely position of the left lane
half_width = np.int(histogram.shape[0]/2)
leftx_base = np.argmax(histogram[:half_width])

# Peak in the second half indicates the likely position of the right lane
rightx_base = np.argmax(histogram[half_width:]) + half_width

print(leftx_base, rightx_base)
plt.plot(histogram)
# Out:
# 343 859

# %%
# Create an output image to draw on and  visualize the result
binary_warped = warped
out_img = np.dstack((binary_warped, binary_warped, binary_warped))*255
# Find the peak of the left and right halves of the histogram
# These will be the starting point for the left and right lines
#midpoint = np.int(histogram.shape[0]/2)
#leftx_base = np.argmax(histogram[:midpoint])
#rightx_base = np.argmax(histogram[midpoint:]) + midpoint

# Choose the number of sliding windows
nwindows = 9
# Set height of windows
window_height = np.int(binary_warped.shape[0]/nwindows)
# Identify the x and y positions of all nonzero pixels in the image
nonzero = binary_warped.nonzero()
nonzeroy = np.array(nonzero[0])
nonzerox = np.array(nonzero[1])
# Current positions to be updated for each window
leftx_current = leftx_base
rightx_current = rightx_base
# Set the width of the windows +/- margin
margin = 100
# Set minimum number of pixels found to recenter window
minpix = 50

num_rows = warped.shape[0]

# Create empty lists to receive left and right lane pixel indices
left_lane_inds = []
right_lane_inds = []

# Step through the windows one by one
for window in range(nwindows):
    # Identify window boundaries in x and y (and right and left)
    win_y_low = binary_warped.shape[0] - (window+1)*window_height
    win_y_high = binary_warped.shape[0] - window*window_height
    win_xleft_low = leftx_current - margin
    win_xleft_high = leftx_current + margin
    win_xright_low = rightx_current - margin
    win_xright_high = rightx_current + margin
    # Draw the windows on the visualization image
    cv2.rectangle(out_img,(win_xleft_low,win_y_low),(win_xleft_high,win_y_high),
    (0,255,0), 2) 
    cv2.rectangle(out_img,(win_xright_low,win_y_low),(win_xright_high,win_y_high),
    (0,255,0), 2) 
    # Identify the nonzero pixels in x and y within the window
    good_left_inds = ((nonzeroy >= win_y_low) & (nonzeroy < win_y_high) & 
    (nonzerox >= win_xleft_low) &  (nonzerox < win_xleft_high)).nonzero()[0]
    good_right_inds = ((nonzeroy >= win_y_low) & (nonzeroy < win_y_high) & 
    (nonzerox >= win_xright_low) &  (nonzerox < win_xright_high)).nonzero()[0]
    # Append these indices to the lists
    left_lane_inds.append(good_left_inds)
    right_lane_inds.append(good_right_inds)
    # If you found > minpix pixels, recenter next window on their mean position
    if len(good_left_inds) > minpix:
        leftx_current = np.int(np.mean(nonzerox[good_left_inds]))
    if len(good_right_inds) > minpix:        
        rightx_current = np.int(np.mean(nonzerox[good_right_inds]))

# Concatenate the arrays of indices
left_lane_inds = np.concatenate(left_lane_inds)
right_lane_inds = np.concatenate(right_lane_inds)

# Extract left and right line pixel positions
leftx = nonzerox[left_lane_inds]
lefty = nonzeroy[left_lane_inds] 
rightx = nonzerox[right_lane_inds]
righty = nonzeroy[right_lane_inds] 

# Fit a second order polynomial to each
left_fit = np.polyfit(lefty, leftx, 2)
right_fit = np.polyfit(righty, rightx, 2)

# %%
# Generate x and y values for plotting
ploty = np.linspace(0, binary_warped.shape[0]-1, binary_warped.shape[0] )
left_fitx = left_fit[0]*ploty**2 + left_fit[1]*ploty + left_fit[2]
right_fitx = right_fit[0]*ploty**2 + right_fit[1]*ploty + right_fit[2]

out_img[nonzeroy[left_lane_inds], nonzerox[left_lane_inds]] = [255, 0, 0]
out_img[nonzeroy[right_lane_inds], nonzerox[right_lane_inds]] = [0, 0, 255]
plt.imshow(out_img)
plt.plot(left_fitx, ploty, color='yellow')
plt.plot(right_fitx, ploty, color='yellow')
plt.xlim(0, 1280)
plt.ylim(720, 0)
# Out:
# (720, 0)

# %%
# Assume you now have a new warped binary image 
# from the next frame of video (also called "binary_warped")
# It's now much easier to find line pixels!
nonzero = binary_warped.nonzero()
nonzeroy = np.array(nonzero[0])
nonzerox = np.array(nonzero[1])
margin = 50
left_lane_inds = ((nonzerox > (left_fit[0]*(nonzeroy**2) + left_fit[1]*nonzeroy + 
left_fit[2] - margin)) & (nonzerox < (left_fit[0]*(nonzeroy**2) + 
left_fit[1]*nonzeroy + left_fit[2] + margin))) 

right_lane_inds = ((nonzerox > (right_fit[0]*(nonzeroy**2) + right_fit[1]*nonzeroy + 
right_fit[2] - margin)) & (nonzerox < (right_fit[0]*(nonzeroy**2) + 
right_fit[1]*nonzeroy + right_fit[2] + margin)))  

# Again, extract left and right line pixel positions
leftx = nonzerox[left_lane_inds]
lefty = nonzeroy[left_lane_inds] 
rightx = nonzerox[right_lane_inds]
righty = nonzeroy[right_lane_inds]
# Fit a second order polynomial to each
left_fit = np.polyfit(lefty, leftx, 2)
right_fit = np.polyfit(righty, rightx, 2)
# Generate x and y values for plotting
ploty = np.linspace(0, binary_warped.shape[0]-1, binary_warped.shape[0] )
left_fitx = left_fit[0]*ploty**2 + left_fit[1]*ploty + left_fit[2]
right_fitx = right_fit[0]*ploty**2 + right_fit[1]*ploty + right_fit[2]

# %%
# Create an image to draw on and an image to show the selection window
out_img = np.dstack((binary_warped, binary_warped, binary_warped))*255
window_img = np.zeros_like(out_img)
# Color in left and right line pixels
out_img[nonzeroy[left_lane_inds], nonzerox[left_lane_inds]] = [255, 0, 0]
out_img[nonzeroy[right_lane_inds], nonzerox[right_lane_inds]] = [0, 0, 255]

# Generate a polygon to illustrate the search window area
# And recast the x and y points into usable format for cv2.fillPoly()
left_line_window1 = np.array([np.transpose(np.vstack([left_fitx-margin, ploty]))])
left_line_window2 = np.array([np.flipud(np.transpose(np.vstack([left_fitx+margin, 
                              ploty])))])
left_line_pts = np.hstack((left_line_window1, left_line_window2))
right_line_window1 = np.array([np.transpose(np.vstack([right_fitx-margin, ploty]))])
right_line_window2 = np.array([np.flipud(np.transpose(np.vstack([right_fitx+margin, 
                              ploty])))])
right_line_pts = np.hstack((right_line_window1, right_line_window2))

# Draw the lane onto the warped blank image
cv2.fillPoly(window_img, np.int_([left_line_pts]), (0,255, 0))
cv2.fillPoly(window_img, np.int_([right_line_pts]), (0,255, 0))
result = cv2.addWeighted(out_img, 1, window_img, 0.3, 0)
plt.imshow(result)
plt.plot(left_fitx, ploty, color='yellow')
plt.plot(right_fitx, ploty, color='yellow')
plt.xlim(0, 1280)
plt.ylim(720, 0)
# Out:
# (720, 0)

# %%
def measure_radius_of_curvature(x_values):
    ym_per_pix = 30/720 # meters per pixel in y dimension
    xm_per_pix = 3.7/700 # meters per pixel in x dimension
    # If no pixels were found return None
    y_points = np.linspace(0, num_rows-1, num_rows)
    y_eval = np.max(y_points)

    # Fit new polynomials to x,y in world space
    fit_cr = np.polyfit(y_points*ym_per_pix, x_values*xm_per_pix, 2)
    curverad = ((1 + (2*fit_cr[0]*y_eval*ym_per_pix + fit_cr[1])**2)**1.5) / np.absolute(2*fit_cr[0])
    return curverad
'''
left_curve_rad = measure_radius_of_curvature(left_fitx)
right_curve_rad = measure_radius_of_curvature(right_fitx)
average_curve_rad = (left_curve_rad + right_curve_rad)/2
curvature_string = "Radius of curvature: %.2f m" % average_curve_rad
print(curvature_string)

# compute the offset from the center
lane_center = (right_fitx[719] + left_fitx[719])/2
xm_per_pix = 3.7/700 # meters per pixel in x dimension
center_offset_pixels = abs(img_size[0]/2 - lane_center)
center_offset_mtrs = xm_per_pix*center_offset_pixels
offset_string = "Center offset: %.2f m" % center_offset_mtrs
print(offset_string)
'''
# Out:
# '\nleft_curve_rad = measure_radius_of_curvature(left_fitx)\nright_curve_rad = measure_radius_of_curvature(right_fitx)\naverage_curve_rad = (left_curve_rad + right_curve_rad)/2\ncurvature_string = "Radius of curvature: %.2f m" % average_curve_rad\nprint(curvature_string)\n\n# compute the offset from the center\nlane_center = (right_fitx[719] + left_fitx[719])/2\nxm_per_pix = 3.7/700 # meters per pixel in x dimension\ncenter_offset_pixels = abs(img_size[0]/2 - lane_center)\ncenter_offset_mtrs = xm_per_pix*center_offset_pixels\noffset_string = "Center offset: %.2f m" % center_offset_mtrs\nprint(offset_string)\n'

# %%
out_img = np.dstack((warped, warped, warped))*255

y_points = np.linspace(0, num_rows-1, num_rows)

left_line_window = np.array(np.transpose(np.vstack([left_fitx, y_points])))

right_line_window = np.array(np.flipud(np.transpose(np.vstack([right_fitx, y_points]))))

line_points = np.vstack((left_line_window, right_line_window))

cv2.fillPoly(out_img, np.int_([line_points]), [0,255, 0])

unwarped = cv2.warpPerspective(out_img, M_inv, img_size , flags=cv2.INTER_LINEAR)

result = cv2.addWeighted(img, 1, unwarped, 0.3, 0)

plt.imshow(result)

# %% [markdown]
# ### Final Pipeline
#
# Read the video and create image for each frame.

# %%
# Import everything needed to edit/save/watch video clips
from moviepy.editor import VideoFileClip
from IPython.display import HTML
import PIL
from PIL import ImageFont
from PIL import Image
from PIL import ImageDraw

# %%
bottom_left = [220,720]
bottom_right = [1200, 720]
top_left = [570, 470]
top_right = [780, 470]

source = np.float32([bottom_left,bottom_right,top_right,top_left])
pts = np.array([bottom_left,bottom_right,top_right,top_left], np.int32)
pts = pts.reshape((-1,1,2))

# Destination points are chosen such that straight lanes appear more or less parallel in the transformed image.
bottom_left = [320,720]
bottom_right = [920, 720]
top_left = [320, 1]
top_right = [920, 1]

dst = np.float32([bottom_left,bottom_right,top_right,top_left])

count = 0 
def pipeline(image):
    global pts, dst, source, image_shape, count
    # NOTE: The output you return should be a color image (3 channel) for processing video below
    # TODO: put your pipeline here,
    # you should return the final output (image where lines are drawn on lanes)
    #flow_img = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    #cv2.imwrite( 'original_image.jpg',flow_img)
    
    thresholded = threshold_image(image)
    img = cv2.undistort(image, cameraMatrix, distortionCoeffs, None, cameraMatrix)
    # Vertices extracted manually for performing a perspective transform

    copy = img.copy()
    cv2.polylines(copy,[pts],True,(255,0,0), thickness=3)

    M = cv2.getPerspectiveTransform(source, dst)
    M_inv = cv2.getPerspectiveTransform(dst, source)
    img_size = (image_shape[1], image_shape[0])
    warped = cv2.warpPerspective(thresholded, M, img_size , flags=cv2.INTER_LINEAR)
    
    histogram = np.sum(warped[warped.shape[0]//2:,:], axis=0)
    #plt.plot(histogram)
    # Peak in the first half indicates the likely position of the left lane and right lane
    half_width = np.int(histogram.shape[0]/2)
    leftx_base = np.argmax(histogram[:half_width])
    rightx_base = np.argmax(histogram[half_width:]) + half_width

    binary_warped = warped
    out_img = np.dstack((binary_warped, binary_warped, binary_warped))*255

    # Choose the number of sliding windows
    nwindows = 9
    # Set height of windows
    window_height = np.int(binary_warped.shape[0]/nwindows)
    # Identify the x and y positions of all nonzero pixels in the image
    nonzero = binary_warped.nonzero()
    nonzeroy = np.array(nonzero[0])
    nonzerox = np.array(nonzero[1])
    # Current positions to be updated for each window
    leftx_current = leftx_base
    rightx_current = rightx_base
    # Set the width of the windows +/- margin
    margin = 100
    # Set minimum number of pixels found to recenter window
    minpix = 50

    num_rows = warped.shape[0]

    # Create empty lists to receive left and right lane pixel indices
    left_lane_inds = []
    right_lane_inds = []

    # Step through the windows one by one
    for window in range(nwindows):
        # Identify window boundaries in x and y (and right and left)
        win_y_low = binary_warped.shape[0] - (window+1)*window_height
        win_y_high = binary_warped.shape[0] - window*window_height
        win_xleft_low = leftx_current - margin
        win_xleft_high = leftx_current + margin
        win_xright_low = rightx_current - margin
        win_xright_high = rightx_current + margin
        # Draw the windows on the visualization image
        cv2.rectangle(out_img,(win_xleft_low,win_y_low),(win_xleft_high,win_y_high),
        (0,255,0), 2) 
        cv2.rectangle(out_img,(win_xright_low,win_y_low),(win_xright_high,win_y_high),
        (0,255,0), 2) 
        # Identify the nonzero pixels in x and y within the window
        good_left_inds = ((nonzeroy >= win_y_low) & (nonzeroy < win_y_high) & 
        (nonzerox >= win_xleft_low) &  (nonzerox < win_xleft_high)).nonzero()[0]
        good_right_inds = ((nonzeroy >= win_y_low) & (nonzeroy < win_y_high) & 
        (nonzerox >= win_xright_low) &  (nonzerox < win_xright_high)).nonzero()[0]
        # Append these indices to the lists
        left_lane_inds.append(good_left_inds)
        right_lane_inds.append(good_right_inds)
        # If you found > minpix pixels, recenter next window on their mean position
        if len(good_left_inds) > minpix:
            leftx_current = np.int(np.mean(nonzerox[good_left_inds]))
        if len(good_right_inds) > minpix:        
            rightx_current = np.int(np.mean(nonzerox[good_right_inds]))

    # Concatenate the arrays of indices
    left_lane_inds = np.concatenate(left_lane_inds)
    right_lane_inds = np.concatenate(right_lane_inds)

    # Extract left and right line pixel positions
    leftx = nonzerox[left_lane_inds]
    lefty = nonzeroy[left_lane_inds] 
    rightx = nonzerox[right_lane_inds]
    righty = nonzeroy[right_lane_inds] 

    if rightx.size == 0 or righty.size == 0 or lefty.size == 0 or leftx.size == 0:
        return image
    # Fit a second order polynomial to each
    try:
        left_fit = np.polyfit(lefty, leftx, 2)
        right_fit = np.polyfit(righty, rightx, 2)
    except ValueError:
        return 
    # Generate x and y values for plotting
    ploty = np.linspace(0, binary_warped.shape[0]-1, binary_warped.shape[0] )
    left_fitx = left_fit[0]*ploty**2 + left_fit[1]*ploty + left_fit[2]
    right_fitx = right_fit[0]*ploty**2 + right_fit[1]*ploty + right_fit[2]

    out_img[nonzeroy[left_lane_inds], nonzerox[left_lane_inds]] = [255, 0, 0]
    out_img[nonzeroy[right_lane_inds], nonzerox[right_lane_inds]] = [0, 0, 255]

    nonzero = binary_warped.nonzero()
    nonzeroy = np.array(nonzero[0])
    nonzerox = np.array(nonzero[1])
    margin = 50
    left_lane_inds = ((nonzerox > (left_fit[0]*(nonzeroy**2) + left_fit[1]*nonzeroy + 
    left_fit[2] - margin)) & (nonzerox < (left_fit[0]*(nonzeroy**2) + 
    left_fit[1]*nonzeroy + left_fit[2] + margin))) 

    right_lane_inds = ((nonzerox > (right_fit[0]*(nonzeroy**2) + right_fit[1]*nonzeroy + 
    right_fit[2] - margin)) & (nonzerox < (right_fit[0]*(nonzeroy**2) + 
    right_fit[1]*nonzeroy + right_fit[2] + margin)))  

    # Again, extract left and right line pixel positions
    leftx = nonzerox[left_lane_inds]
    lefty = nonzeroy[left_lane_inds] 
    rightx = nonzerox[right_lane_inds]
    righty = nonzeroy[right_lane_inds]
    # Fit a second order polynomial to each
    left_fit = np.polyfit(lefty, leftx, 2)
    right_fit = np.polyfit(righty, rightx, 2)
    # Generate x and y values for plotting
    ploty = np.linspace(0, binary_warped.shape[0]-1, binary_warped.shape[0] )
    left_fitx = left_fit[0]*ploty**2 + left_fit[1]*ploty + left_fit[2]
    right_fitx = right_fit[0]*ploty**2 + right_fit[1]*ploty + right_fit[2]
    
    # Create an image to draw on and an image to show the selection window
    out_img = np.dstack((binary_warped, binary_warped, binary_warped))*255
    window_img = np.zeros_like(out_img)
    # Color in left and right line pixels
    out_img[nonzeroy[left_lane_inds], nonzerox[left_lane_inds]] = [255, 0, 0]
    out_img[nonzeroy[right_lane_inds], nonzerox[right_lane_inds]] = [0, 0, 255]

    # Generate a polygon to illustrate the search window area
    # And recast the x and y points into usable format for cv2.fillPoly()
    left_line_window1 = np.array([np.transpose(np.vstack([left_fitx-margin, ploty]))])
    left_line_window2 = np.array([np.flipud(np.transpose(np.vstack([left_fitx+margin, 
                                  ploty])))])
    left_line_pts = np.hstack((left_line_window1, left_line_window2))
    right_line_window1 = np.array([np.transpose(np.vstack([right_fitx-margin, ploty]))])
    right_line_window2 = np.array([np.flipud(np.transpose(np.vstack([right_fitx+margin, 
                                  ploty])))])
    right_line_pts = np.hstack((right_line_window1, right_line_window2))

    # Draw the lane onto the warped blank image
    cv2.fillPoly(window_img, np.int_([left_line_pts]), (0,255, 0))
    cv2.fillPoly(window_img, np.int_([right_line_pts]), (0,255, 0))
    result = cv2.addWeighted(out_img, 1, window_img, 0.3, 0)

    left_curve_rad = measure_radius_of_curvature(left_fitx)
    right_curve_rad = measure_radius_of_curvature(right_fitx)
    average_curve_rad = (left_curve_rad + right_curve_rad)/2
    curvature_string = "Radius of curvature: %.2f m" % average_curve_rad
    #print(curvature_string)

    # compute the offset from the center
    lane_center = (right_fitx[719] + left_fitx[719])/2
    xm_per_pix = 3.7/700 # meters per pixel in x dimension
    center_offset_pixels = abs(img_size[0]/2 - lane_center)
    center_offset_mtrs = xm_per_pix*center_offset_pixels
    offset_string = "Center offset: %.2f m" % center_offset_mtrs
    #print(offset_string)

    out_img = np.dstack((warped, warped, warped))*255

    y_points = np.linspace(0, num_rows-1, num_rows)

    left_line_window = np.array(np.transpose(np.vstack([left_fitx, y_points])))

    right_line_window = np.array(np.flipud(np.transpose(np.vstack([right_fitx, y_points]))))

    line_points = np.vstack((left_line_window, right_line_window))

    cv2.fillPoly(out_img, np.int_([line_points]), [0,255, 0])

    unwarped = cv2.warpPerspective(out_img, M_inv, img_size , flags=cv2.INTER_LINEAR)

    result = cv2.addWeighted(img, 1, unwarped, 0.3, 0)

    # write the result here cv2.write()
    #result = image
    #img_text = "Radius of Curvature : " + 
    texted_image =cv2.putText(img=np.copy(result), text=curvature_string, 
                              org=(100,50),fontFace=2, 
                              fontScale=2, 
                              color=(255,0,0), thickness=3)
    texted_image =cv2.putText(img=np.copy(result), text=curvature_string, 
                              org=(100,50),fontFace=2, 
                              fontScale=2, 
                              color=(255,0,0), thickness=3)
    #plt.imshow(texted_image)

    cv2.imwrite( 'result' + str(count) + '.jpg',result)
    count+=1
    return texted_image

# %%
img = mpimg.imread('test_images/test1.jpg')
result = pipeline(img)
plt.imshow(result)

# %%
#clip1 = "project_video.mp4"
#HTML("""
#<video width="960" height="540" controls>
#  <source src="{0}">
#</video>
#""".format(clip1))

# %%
from moviepy.editor import VideoFileClip
white_output = 'project_output.mp4'
## To speed up the testing process you may want to try your pipeline on a shorter subclip of the video
## To do so add .subclip(start_second,end_second) to the end of the line below
## Where start_second and end_second are integer values representing the start and end of the subclip
## You may also uncomment the following line for a subclip of the first 5 seconds
##clip1 = VideoFileClip("test_videos/solidWhiteRight.mp4").subclip(0,5)
clip1 = VideoFileClip("project_video.mp4")
try:
    white_clip = clip1.fl_image(pipeline) #NOTE: this function expects color images!!
    # %time white_clip.write_videofile(white_output, audio=False)
except ValueError:
    print ("Oops!  That was no valid number.  Try again...")
# Out:
# Radius of curvature: 2688.66 m
# Center offset: 0.01 m
# [MoviePy] >>>> Building video project_output.mp4
# [MoviePy] Writing video project_output.mp4
#   0%|          | 0/1261 [00:00<?, ?it/s]
# Radius of curvature: 2688.66 m
# Center offset: 0.01 m
#   0%|          | 1/1261 [00:00<09:20,  2.25it/s]
# Radius of curvature: 2562.13 m
# Center offset: 0.00 m
#   0%|          | 2/1261 [00:00<09:14,  2.27it/s]
# Radius of curvature: 1655.59 m
# Center offset: 0.01 m
#   0%|          | 3/1261 [00:01<09:25,  2.23it/s]
# Radius of curvature: 1745.82 m
# Center offset: 0.01 m
#   0%|          | 4/1261 [00:01<09:26,  2.22it/s]
# Radius of curvature: 1854.21 m
# Center offset: 0.01 m
#   0%|          | 5/1261 [00:02<09:28,  2.21it/s]
# Radius of curvature: 3031.19 m
# Center offset: 0.00 m
#   0%|          | 6/1261 [00:02<09:33,  2.19it/s]
# Radius of curvature: 1596.76 m
# Center offset: 0.00 m
#   1%|          | 7/1261 [00:03<09:21,  2.23it/s]
# Radius of curvature: 1542.27 m
# Center offset: 0.01 m
#   1%|          | 8/1261 [00:03<09:18,  2.24it/s]
# Radius of curvature: 1715.20 m
# Center offset: 0.01 m
#   1%|          | 9/1261 [00:04<09:37,  2.17it/s]
# Radius of curvature: 2047.85 m
# Center offset: 0.02 m
#   1%|          | 10/1261 [00:04<09:57,  2.09it/s]
# Radius of curvature: 1848.54 m
# Center offset: 0.02 m
#   1%|          | 11/1261 [00:05<09:43,  2.14it/s]
# Radius of curvature: 1956.68 m
# Center offset: 0.02 m
#   1%|          | 12/1261 [00:05<09:31,  2.19it/s]
# Radius of curvature: 1640.09 m
# Center offset: 0.00 m
#   1%|          | 13/1261 [00:05<09:33,  2.18it/s]
# Radius of curvature: 1996.37 m
# Center offset: 0.01 m
#   1%|          | 14/1261 [00:06<10:39,  1.95it/s]
# Radius of curvature: 1710.02 m
# Center offset: 0.00 m
#   1%|          | 15/1261 [00:07<10:51,  1.91it/s]
# Radius of curvature: 2005.49 m
# Center offset: 0.00 m
#   1%|▏         | 16/1261 [00:07<11:17,  1.84it/s]
# Radius of curvature: 2245.98 m
# Center offset: 0.01 m
#   1%|▏         | 17/1261 [00:08<11:33,  1.79it/s]
# Radius of curvature: 2068.23 m
# Center offset: 0.01 m
#   1%|▏         | 18/1261 [00:08<11:19,  1.83it/s]
# Radius of curvature: 2643.35 m
# Center offset: 0.01 m
#   2%|▏         | 19/1261 [00:09<11:13,  1.84it/s]
# Radius of curvature: 2663.37 m
# Center offset: 0.01 m
#   2%|▏         | 20/1261 [00:09<11:46,  1.76it/s]
# Radius of curvature: 3969.37 m
# Center offset: 0.02 m
#   2%|▏         | 21/1261 [00:10<11:15,  1.84it/s]
# Radius of curvature: 19401.57 m
# Center offset: 0.01 m
#   2%|▏         | 22/1261 [00:10<10:47,  1.91it/s]
# Radius of curvature: 12000.53 m
# Center offset: 0.00 m
#   2%|▏         | 23/1261 [00:11<10:34,  1.95it/s]
# Radius of curvature: 3374.91 m
# Center offset: 0.00 m
#   2%|▏         | 24/1261 [00:12<11:00,  1.87it/s]
# Radius of curvature: 4135.09 m
# Center offset: 0.03 m
#   2%|▏         | 25/1261 [00:12<10:41,  1.93it/s]
# Radius of curvature: 2837.56 m
# Center offset: 0.06 m
#   2%|▏         | 26/1261 [00:13<11:29,  1.79it/s]
# Radius of curvature: 3062.09 m
# Center offset: 0.04 m
#   2%|▏         | 27/1261 [00:13<10:33,  1.95it/s]
# Radius of curvature: 3224.10 m
# Center offset: 0.04 m
#   2%|▏         | 28/1261 [00:14<10:11,  2.02it/s]
# Radius of curvature: 2398.77 m
# Center offset: 0.05 m
#   2%|▏         | 29/1261 [00:14<10:12,  2.01it/s]
# Radius of curvature: 2088.12 m
# Center offset: 0.05 m
#   2%|▏         | 30/1261 [00:15<10:20,  1.98it/s]
# Radius of curvature: 2262.60 m
# Center offset: 0.05 m
#   2%|▏         | 31/1261 [00:15<10:29,  1.95it/s]
# Radius of curvature: 1554.48 m
# Center offset: 0.06 m
#   3%|▎         | 32/1261 [00:16<10:28,  1.96it/s]
# Radius of curvature: 2211.71 m
# Center offset: 0.05 m
#   3%|▎         | 33/1261 [00:16<10:55,  1.87it/s]
# Radius of curvature: 1820.84 m
# Center offset: 0.04 m
#   3%|▎         | 34/1261 [00:17<10:56,  1.87it/s]
# Radius of curvature: 12181.65 m
# Center offset: 0.02 m
#   3%|▎         | 35/1261 [00:17<12:28,  1.64it/s]
# Radius of curvature: 2985.65 m
# Center offset: 0.02 m
#   3%|▎         | 36/1261 [00:18<12:23,  1.65it/s]
# Radius of curvature: 1970.11 m
# Center offset: 0.03 m
#   3%|▎         | 37/1261 [00:19<12:54,  1.58it/s]
# Radius of curvature: 1574.11 m
# Center offset: 0.05 m
#   3%|▎         | 38/1261 [00:19<12:50,  1.59it/s]
# Radius of curvature: 1693.93 m
# Center offset: 0.05 m
#   3%|▎         | 39/1261 [00:20<13:07,  1.55it/s]
# Radius of curvature: 1759.43 m
# Center offset: 0.05 m
#   3%|▎         | 40/1261 [00:21<12:38,  1.61it/s]
# Radius of curvature: 1804.93 m
# Center offset: 0.04 m
#   3%|▎         | 41/1261 [00:21<12:23,  1.64it/s]
# Radius of curvature: 1813.83 m
# Center offset: 0.04 m
#   3%|▎         | 42/1261 [00:22<14:48,  1.37it/s]
# Radius of curvature: 1677.45 m
# Center offset: 0.04 m
#   3%|▎         | 43/1261 [00:23<14:50,  1.37it/s]
# Radius of curvature: 1724.63 m
# Center offset: 0.04 m
#   3%|▎         | 44/1261 [00:24<14:49,  1.37it/s]
# Radius of curvature: 1288.72 m
# Center offset: 0.04 m
#   4%|▎         | 45/1261 [00:25<15:38,  1.30it/s]
# Radius of curvature: 3029.95 m
# Center offset: 0.00 m
#   4%|▎         | 46/1261 [00:25<14:47,  1.37it/s]
# Radius of curvature: 1765.12 m
# Center offset: 0.01 m
#   4%|▎         | 47/1261 [00:26<14:44,  1.37it/s]
# Radius of curvature: 3548.04 m
# Center offset: 0.01 m
#   4%|▍         | 48/1261 [00:27<14:19,  1.41it/s]
# Radius of curvature: 13346.09 m
# Center offset: 0.01 m
#   4%|▍         | 49/1261 [00:27<15:16,  1.32it/s]
# Radius of curvature: 223306.78 m
# Center offset: 0.01 m
#   4%|▍         | 50/1261 [00:28<14:31,  1.39it/s]
# Radius of curvature: 1356.13 m
# Center offset: 0.04 m
#   4%|▍         | 51/1261 [00:29<14:17,  1.41it/s]
# Radius of curvature: 1577.12 m
# Center offset: 0.03 m
#   4%|▍         | 52/1261 [00:31<21:55,  1.09s/it]
# Radius of curvature: 1595.76 m
# Center offset: 0.03 m
#   4%|▍         | 53/1261 [00:32<21:37,  1.07s/it]
# Radius of curvature: 1836.92 m
# Center offset: 0.03 m
#   4%|▍         | 54/1261 [00:32<18:47,  1.07it/s]
# Radius of curvature: 1755.60 m
# Center offset: 0.03 m
#   4%|▍         | 55/1261 [00:33<16:55,  1.19it/s]
# Radius of curvature: 2010.80 m
# Center offset: 0.03 m
#   4%|▍         | 56/1261 [00:34<15:59,  1.26it/s]
# Radius of curvature: 1701.70 m
# Center offset: 0.03 m
#   5%|▍         | 57/1261 [00:34<14:34,  1.38it/s]
# Radius of curvature: 1762.49 m
# Center offset: 0.03 m
#   5%|▍         | 58/1261 [00:35<13:11,  1.52it/s]
# Radius of curvature: 3334.30 m
# Center offset: 0.01 m
#   5%|▍         | 59/1261 [00:35<12:38,  1.58it/s]
# Radius of curvature: 3056.58 m
# Center offset: 0.01 m
#   5%|▍         | 60/1261 [00:36<12:32,  1.60it/s]
# Radius of curvature: 2728.39 m
# Center offset: 0.04 m
#   5%|▍         | 61/1261 [00:36<11:38,  1.72it/s]
# Radius of curvature: 2705.97 m
# Center offset: 0.04 m
#   5%|▍         | 62/1261 [00:37<11:41,  1.71it/s]
# Radius of curvature: 2434.37 m
# Center offset: 0.06 m
#   5%|▍         | 63/1261 [00:38<12:03,  1.66it/s]
# Radius of curvature: 2377.35 m
# Center offset: 0.06 m
#   5%|▌         | 64/1261 [00:38<12:24,  1.61it/s]
# Radius of curvature: 2288.37 m
# Center offset: 0.07 m
#   5%|▌         | 65/1261 [00:39<12:24,  1.61it/s]
# Radius of curvature: 2231.26 m
# Center offset: 0.08 m
#   5%|▌         | 66/1261 [00:40<12:29,  1.59it/s]
# Radius of curvature: 2054.11 m
# Center offset: 0.09 m
#   5%|▌         | 67/1261 [00:40<12:27,  1.60it/s]
# Radius of curvature: 2260.23 m
# Center offset: 0.09 m
#   5%|▌         | 68/1261 [00:41<11:52,  1.67it/s]
# Radius of curvature: 2097.68 m
# Center offset: 0.10 m
#   5%|▌         | 69/1261 [00:41<11:24,  1.74it/s]
# Radius of curvature: 2792.46 m
# Center offset: 0.10 m
#   6%|▌         | 70/1261 [00:42<11:07,  1.78it/s]
# Radius of curvature: 6579.93 m
# Center offset: 0.09 m
#   6%|▌         | 71/1261 [00:42<10:50,  1.83it/s]
# Radius of curvature: 1772.82 m
# Center offset: 0.08 m
#   6%|▌         | 72/1261 [00:43<10:37,  1.86it/s]
# Radius of curvature: 1420.63 m
# Center offset: 0.07 m
#   6%|▌         | 73/1261 [00:43<10:33,  1.87it/s]
# Radius of curvature: 6529.13 m
# Center offset: 0.10 m
#   6%|▌         | 74/1261 [00:44<10:31,  1.88it/s]
# Radius of curvature: 4090.25 m
# Center offset: 0.10 m
#   6%|▌         | 75/1261 [00:44<10:09,  1.94it/s]
# Radius of curvature: 2009.46 m
# Center offset: 0.12 m
#   6%|▌         | 76/1261 [00:45<09:41,  2.04it/s]
# Radius of curvature: 2476.65 m
# Center offset: 0.12 m
#   6%|▌         | 77/1261 [00:45<09:52,  2.00it/s]
# Radius of curvature: 2785.99 m
# Center offset: 0.12 m
#   6%|▌         | 78/1261 [00:46<10:04,  1.96it/s]
# Radius of curvature: 3337.35 m
# Center offset: 0.12 m
#   6%|▋         | 79/1261 [00:46<10:17,  1.92it/s]
# Radius of curvature: 3574.80 m
# Center offset: 0.13 m
#   6%|▋         | 80/1261 [00:47<10:16,  1.92it/s]
# Radius of curvature: 6422.48 m
# Center offset: 0.13 m
#   6%|▋         | 81/1261 [00:47<10:20,  1.90it/s]
# Radius of curvature: 5246.75 m
# Center offset: 0.14 m
#   7%|▋         | 82/1261 [00:48<10:06,  1.94it/s]
# Radius of curvature: 5697.84 m
# Center offset: 0.14 m
#   7%|▋         | 83/1261 [00:48<09:45,  2.01it/s]
# Radius of curvature: 14728.45 m
# Center offset: 0.11 m
#   7%|▋         | 84/1261 [00:49<10:00,  1.96it/s]
# Radius of curvature: 6137.57 m
# Center offset: 0.13 m
#   7%|▋         | 85/1261 [00:49<09:43,  2.02it/s]
# Radius of curvature: 6677.85 m
# Center offset: 0.13 m
#   7%|▋         | 86/1261 [00:50<09:29,  2.06it/s]
# Radius of curvature: 3149.05 m
# Center offset: 0.15 m
#   7%|▋         | 87/1261 [00:50<09:16,  2.11it/s]
# Radius of curvature: 2222.21 m
# Center offset: 0.18 m
#   7%|▋         | 88/1261 [00:51<10:50,  1.80it/s]
# Radius of curvature: 2125.60 m
# Center offset: 0.17 m
#   7%|▋         | 89/1261 [00:52<11:31,  1.70it/s]
# Radius of curvature: 1867.69 m
# Center offset: 0.17 m
#   7%|▋         | 90/1261 [00:53<13:02,  1.50it/s]
# Radius of curvature: 2105.00 m
# Center offset: 0.16 m
#   7%|▋         | 91/1261 [00:53<12:18,  1.59it/s]
# Radius of curvature: 2331.23 m
# Center offset: 0.16 m
#   7%|▋         | 92/1261 [00:54<12:49,  1.52it/s]
# Radius of curvature: 1849.26 m
# Center offset: 0.16 m
#   7%|▋         | 93/1261 [00:55<14:56,  1.30it/s]
# Radius of curvature: 1985.64 m
# Center offset: 0.16 m
#   7%|▋         | 94/1261 [00:56<14:39,  1.33it/s]
# Radius of curvature: 4945.12 m
# Center offset: 0.16 m
#   8%|▊         | 95/1261 [00:56<13:42,  1.42it/s]
# Radius of curvature: 1752.45 m
# Center offset: 0.11 m
#   8%|▊         | 96/1261 [00:58<18:33,  1.05it/s]
# Radius of curvature: 3225.71 m
# Center offset: 0.13 m
#   8%|▊         | 97/1261 [01:00<26:28,  1.36s/it]
# Radius of curvature: 2000.09 m
# Center offset: 0.13 m
#   8%|▊         | 98/1261 [01:01<22:43,  1.17s/it]
# Radius of curvature: 2000.35 m
# Center offset: 0.15 m
#   8%|▊         | 99/1261 [01:01<19:38,  1.01s/it]
# Radius of curvature: 2134.01 m
# Center offset: 0.15 m
#   8%|▊         | 100/1261 [01:02<17:03,  1.13it/s]
# Radius of curvature: 1486.83 m
# Center offset: 0.18 m
#   8%|▊         | 101/1261 [01:03<15:27,  1.25it/s]
# Radius of curvature: 1509.50 m
# Center offset: 0.17 m
#   8%|▊         | 102/1261 [01:03<14:10,  1.36it/s]
# Radius of curvature: 1722.99 m
# Center offset: 0.16 m
#   8%|▊         | 103/1261 [01:04<12:50,  1.50it/s]
# Radius of curvature: 1917.56 m
# Center offset: 0.15 m
#   8%|▊         | 104/1261 [01:04<12:15,  1.57it/s]
# Radius of curvature: 2081.31 m
# Center offset: 0.14 m
#   8%|▊         | 105/1261 [01:05<11:32,  1.67it/s]
# Radius of curvature: 2541.64 m
# Center offset: 0.13 m
#   8%|▊         | 106/1261 [01:05<12:09,  1.58it/s]
# Radius of curvature: 3292.31 m
# Center offset: 0.12 m
#   8%|▊         | 107/1261 [01:06<12:58,  1.48it/s]
# Radius of curvature: 1632.48 m
# Center offset: 0.12 m
#   9%|▊         | 108/1261 [01:07<12:09,  1.58it/s]
# Radius of curvature: 2971.80 m
# Center offset: 0.08 m
#   9%|▊         | 109/1261 [01:08<12:54,  1.49it/s]
# Radius of curvature: 2406.44 m
# Center offset: 0.09 m
#   9%|▊         | 110/1261 [01:08<13:46,  1.39it/s]
# Radius of curvature: 19548.19 m
# Center offset: 0.09 m
#   9%|▉         | 111/1261 [01:09<13:41,  1.40it/s]
# Radius of curvature: 5185.79 m
# Center offset: 0.08 m
#   9%|▉         | 112/1261 [01:10<13:54,  1.38it/s]
# Radius of curvature: 3552.65 m
# Center offset: 0.09 m
#   9%|▉         | 113/1261 [01:11<14:20,  1.33it/s]
# Radius of curvature: 2417.55 m
# Center offset: 0.09 m
#   9%|▉         | 114/1261 [01:11<13:50,  1.38it/s]
# Radius of curvature: 2840.01 m
# Center offset: 0.08 m
#   9%|▉         | 115/1261 [01:13<21:46,  1.14s/it]
# Radius of curvature: 2062.11 m
# Center offset: 0.09 m
#   9%|▉         | 116/1261 [01:14<19:25,  1.02s/it]
# Radius of curvature: 2035.08 m
# Center offset: 0.09 m
#   9%|▉         | 117/1261 [01:15<17:13,  1.11it/s]
# Radius of curvature: 2180.38 m
# Center offset: 0.09 m
#   9%|▉         | 118/1261 [01:15<15:56,  1.20it/s]
# Radius of curvature: 2912.38 m
# Center offset: 0.09 m
#   9%|▉         | 119/1261 [01:16<16:13,  1.17it/s]
# Radius of curvature: 1485.00 m
# Center offset: 0.09 m
#  10%|▉         | 120/1261 [01:17<16:44,  1.14it/s]
# Radius of curvature: 1631.47 m
# Center offset: 0.08 m
#  10%|▉         | 121/1261 [01:18<15:02,  1.26it/s]
# Radius of curvature: 1894.68 m
# Center offset: 0.06 m
#  10%|▉         | 122/1261 [01:18<13:54,  1.37it/s]
# Radius of curvature: 4496.02 m
# Center offset: 0.05 m
#  10%|▉         | 123/1261 [01:19<14:36,  1.30it/s]
# Radius of curvature: 2799.98 m
# Center offset: 0.04 m
#  10%|▉         | 124/1261 [01:20<13:09,  1.44it/s]
# Radius of curvature: 1597.85 m
# Center offset: 0.06 m
#  10%|▉         | 125/1261 [01:20<12:27,  1.52it/s]
# Radius of curvature: 1472.53 m
# Center offset: 0.07 m
#  10%|▉         | 126/1261 [01:21<11:04,  1.71it/s]
# Radius of curvature: 1439.04 m
# Center offset: 0.06 m
#  10%|█         | 127/1261 [01:21<10:06,  1.87it/s]
# Radius of curvature: 1436.27 m
# Center offset: 0.06 m
#  10%|█         | 128/1261 [01:22<09:37,  1.96it/s]
# Radius of curvature: 1536.79 m
# Center offset: 0.05 m
#  10%|█         | 129/1261 [01:22<08:56,  2.11it/s]
# Radius of curvature: 1602.69 m
# Center offset: 0.05 m
#  10%|█         | 130/1261 [01:23<08:31,  2.21it/s]
# Radius of curvature: 1334.16 m
# Center offset: 0.05 m
#  10%|█         | 131/1261 [01:23<08:48,  2.14it/s]
# Radius of curvature: 1320.12 m
# Center offset: 0.04 m
#  10%|█         | 132/1261 [01:23<08:48,  2.14it/s]
# Radius of curvature: 1359.24 m
# Center offset: 0.04 m
#  11%|█         | 133/1261 [01:24<08:52,  2.12it/s]
# Radius of curvature: 2171.37 m
# Center offset: 0.01 m
#  11%|█         | 134/1261 [01:24<08:41,  2.16it/s]
# Radius of curvature: 8388.37 m
# Center offset: 0.01 m
#  11%|█         | 135/1261 [01:25<08:14,  2.28it/s]
# Radius of curvature: 6620.47 m
# Center offset: 0.01 m
#  11%|█         | 136/1261 [01:25<08:24,  2.23it/s]
# Radius of curvature: 3880.47 m
# Center offset: 0.00 m
#  11%|█         | 137/1261 [01:26<08:23,  2.23it/s]
# Radius of curvature: 2490.69 m
# Center offset: 0.00 m
#  11%|█         | 138/1261 [01:26<08:25,  2.22it/s]
# Radius of curvature: 1889.06 m
# Center offset: 0.01 m
#  11%|█         | 139/1261 [01:27<08:29,  2.20it/s]
# Radius of curvature: 2222.51 m
# Center offset: 0.01 m
#  11%|█         | 140/1261 [01:27<08:29,  2.20it/s]
# Radius of curvature: 2158.80 m
# Center offset: 0.01 m
#  11%|█         | 141/1261 [01:28<08:32,  2.19it/s]
# Radius of curvature: 1983.94 m
# Center offset: 0.02 m
#  11%|█▏        | 142/1261 [01:28<08:52,  2.10it/s]
# Radius of curvature: 2126.07 m
# Center offset: 0.02 m
#  11%|█▏        | 143/1261 [01:29<09:27,  1.97it/s]
# Radius of curvature: 2886.43 m
# Center offset: 0.03 m
#  11%|█▏        | 144/1261 [01:29<09:34,  1.95it/s]
# Radius of curvature: 1694.75 m
# Center offset: 0.03 m
#  11%|█▏        | 145/1261 [01:30<09:19,  1.99it/s]
# Radius of curvature: 2143.11 m
# Center offset: 0.03 m
#  12%|█▏        | 146/1261 [01:30<09:16,  2.00it/s]
# Radius of curvature: 2381.29 m
# Center offset: 0.01 m
#  12%|█▏        | 147/1261 [01:31<09:28,  1.96it/s]
# Radius of curvature: 2385.71 m
# Center offset: 0.01 m
#  12%|█▏        | 148/1261 [01:31<09:08,  2.03it/s]
# Radius of curvature: 2277.95 m
# Center offset: 0.01 m
#  12%|█▏        | 149/1261 [01:32<08:33,  2.17it/s]
# Radius of curvature: 5136.86 m
# Center offset: 0.01 m
#  12%|█▏        | 150/1261 [01:32<08:08,  2.27it/s]
# Radius of curvature: 3981.02 m
# Center offset: 0.01 m
#  12%|█▏        | 151/1261 [01:32<07:54,  2.34it/s]
# Radius of curvature: 2926.71 m
# Center offset: 0.02 m
#  12%|█▏        | 152/1261 [01:33<07:47,  2.37it/s]
# Radius of curvature: 2790.40 m
# Center offset: 0.03 m
#  12%|█▏        | 153/1261 [01:33<07:55,  2.33it/s]
# Radius of curvature: 2717.69 m
# Center offset: 0.03 m
#  12%|█▏        | 154/1261 [01:34<07:46,  2.37it/s]
# Radius of curvature: 3411.68 m
# Center offset: 0.03 m
#  12%|█▏        | 155/1261 [01:34<07:41,  2.40it/s]
# Radius of curvature: 3056.15 m
# Center offset: 0.04 m
#  12%|█▏        | 156/1261 [01:34<07:36,  2.42it/s]
# Radius of curvature: 2785.14 m
# Center offset: 0.04 m
#  12%|█▏        | 157/1261 [01:35<07:43,  2.38it/s]
# Radius of curvature: 2027.24 m
# Center offset: 0.06 m
#  13%|█▎        | 159/1261 [01:36<07:31,  2.44it/s]
# Radius of curvature: 3290.37 m
# Center offset: 0.04 m
#  13%|█▎        | 160/1261 [01:36<07:38,  2.40it/s]
# Radius of curvature: 22034.26 m
# Center offset: 0.04 m
#  13%|█▎        | 161/1261 [01:36<07:43,  2.37it/s]
# Radius of curvature: 4577.00 m
# Center offset: 0.06 m
#  13%|█▎        | 162/1261 [01:37<07:38,  2.40it/s]
# Radius of curvature: 3137.80 m
# Center offset: 0.05 m
#  13%|█▎        | 163/1261 [01:37<08:26,  2.17it/s]
# Radius of curvature: 2657.56 m
# Center offset: 0.05 m
#  13%|█▎        | 164/1261 [01:38<08:18,  2.20it/s]
# Radius of curvature: 2326.57 m
# Center offset: 0.07 m
#  13%|█▎        | 165/1261 [01:38<08:11,  2.23it/s]
# Radius of curvature: 2911.61 m
# Center offset: 0.07 m
#  13%|█▎        | 166/1261 [01:39<08:13,  2.22it/s]
# Radius of curvature: 3089.64 m
# Center offset: 0.07 m
#  13%|█▎        | 167/1261 [01:39<08:03,  2.26it/s]
# Radius of curvature: 2582.89 m
# Center offset: 0.07 m
#  13%|█▎        | 168/1261 [01:40<07:41,  2.37it/s]
# Radius of curvature: 19634.53 m
# Center offset: 0.07 m
#  13%|█▎        | 169/1261 [01:40<07:26,  2.44it/s]
# Radius of curvature: 3546.13 m
# Center offset: 0.08 m
#  13%|█▎        | 170/1261 [01:40<07:28,  2.43it/s]
# Radius of curvature: 7280.30 m
# Center offset: 0.09 m
#  14%|█▎        | 171/1261 [01:41<07:42,  2.36it/s]
# Radius of curvature: 2512.74 m
# Center offset: 0.09 m
#  14%|█▎        | 172/1261 [01:41<07:29,  2.42it/s]
# Radius of curvature: 7041.81 m
# Center offset: 0.08 m
#  14%|█▎        | 173/1261 [01:42<07:44,  2.34it/s]
# Radius of curvature: 2347.25 m
# Center offset: 0.08 m
#  14%|█▍        | 174/1261 [01:42<08:22,  2.16it/s]
# Radius of curvature: 4248.05 m
# Center offset: 0.09 m
#  14%|█▍        | 175/1261 [01:43<08:22,  2.16it/s]
# Radius of curvature: 2474.30 m
# Center offset: 0.11 m
#  14%|█▍        | 176/1261 [01:43<08:15,  2.19it/s]
# Radius of curvature: 2460.80 m
# Center offset: 0.11 m
#  14%|█▍        | 177/1261 [01:44<08:27,  2.14it/s]
# Radius of curvature: 2656.87 m
# Center offset: 0.11 m
#  14%|█▍        | 178/1261 [01:44<08:49,  2.05it/s]
# Radius of curvature: 2722.31 m
# Center offset: 0.11 m
#  14%|█▍        | 179/1261 [01:45<08:49,  2.04it/s]
# Radius of curvature: 2828.15 m
# Center offset: 0.10 m
#  14%|█▍        | 180/1261 [01:45<09:18,  1.94it/s]
# Radius of curvature: 2366.11 m
# Center offset: 0.10 m
#  14%|█▍        | 181/1261 [01:46<09:33,  1.88it/s]
# Radius of curvature: 2122.22 m
# Center offset: 0.11 m
#  14%|█▍        | 182/1261 [01:46<09:14,  1.95it/s]
# Radius of curvature: 1825.90 m
# Center offset: 0.11 m
#  15%|█▍        | 183/1261 [01:47<10:25,  1.72it/s]
# Radius of curvature: 2101.18 m
# Center offset: 0.08 m
#  15%|█▍        | 184/1261 [01:47<09:49,  1.83it/s]
# Radius of curvature: 1636.23 m
# Center offset: 0.10 m
#  15%|█▍        | 185/1261 [01:48<08:55,  2.01it/s]
# Radius of curvature: 1901.71 m
# Center offset: 0.10 m
#  15%|█▍        | 186/1261 [01:48<08:39,  2.07it/s]
# Radius of curvature: 1599.29 m
# Center offset: 0.10 m
#  15%|█▍        | 187/1261 [01:49<08:12,  2.18it/s]
# Radius of curvature: 970.77 m
# Center offset: 0.12 m
#  15%|█▍        | 188/1261 [01:49<07:58,  2.24it/s]
# Radius of curvature: 1200.71 m
# Center offset: 0.10 m
#  15%|█▍        | 189/1261 [01:50<10:02,  1.78it/s]
# Radius of curvature: 1031.72 m
# Center offset: 0.10 m
#  15%|█▌        | 190/1261 [01:51<10:37,  1.68it/s]
# Radius of curvature: 1099.23 m
# Center offset: 0.09 m
#  15%|█▌        | 191/1261 [01:51<11:27,  1.56it/s]
# Radius of curvature: 1139.28 m
# Center offset: 0.08 m
#  15%|█▌        | 192/1261 [01:52<10:45,  1.66it/s]
# Radius of curvature: 1200.00 m
# Center offset: 0.07 m
#  15%|█▌        | 193/1261 [01:52<09:53,  1.80it/s]
# Radius of curvature: 1255.65 m
# Center offset: 0.07 m
#  15%|█▌        | 194/1261 [01:53<09:17,  1.91it/s]
# Radius of curvature: 1249.16 m
# Center offset: 0.06 m
#  15%|█▌        | 195/1261 [01:53<08:47,  2.02it/s]
# Radius of curvature: 1789.62 m
# Center offset: 0.01 m
#  16%|█▌        | 196/1261 [01:54<08:34,  2.07it/s]
# Radius of curvature: 3999.37 m
# Center offset: 0.03 m
#  16%|█▌        | 197/1261 [01:54<08:39,  2.05it/s]
# Radius of curvature: 4891.55 m
# Center offset: 0.04 m
#  16%|█▌        | 198/1261 [01:55<08:36,  2.06it/s]
# Radius of curvature: 110017.20 m
# Center offset: 0.05 m
#  16%|█▌        | 199/1261 [01:55<08:53,  1.99it/s]
# Radius of curvature: 5234.60 m
# Center offset: 0.06 m
#  16%|█▌        | 200/1261 [01:56<09:11,  1.92it/s]
# Radius of curvature: 2150.63 m
# Center offset: 0.07 m
#  16%|█▌        | 201/1261 [01:56<09:30,  1.86it/s]
# Radius of curvature: 2047.97 m
# Center offset: 0.07 m
#  16%|█▌        | 202/1261 [01:57<09:43,  1.81it/s]
# Radius of curvature: 2161.69 m
# Center offset: 0.08 m
#  16%|█▌        | 203/1261 [01:57<09:49,  1.79it/s]
# Radius of curvature: 2105.82 m
# Center offset: 0.09 m
#  16%|█▌        | 204/1261 [01:58<09:52,  1.79it/s]
# Radius of curvature: 2024.22 m
# Center offset: 0.09 m
#  16%|█▋        | 205/1261 [01:59<10:01,  1.76it/s]
# Radius of curvature: 1753.10 m
# Center offset: 0.09 m
#  16%|█▋        | 206/1261 [01:59<10:13,  1.72it/s]
# Radius of curvature: 1606.88 m
# Center offset: 0.09 m
#  16%|█▋        | 208/1261 [02:00<09:32,  1.84it/s]
# Radius of curvature: 3138.74 m
# Center offset: 0.06 m
#  17%|█▋        | 209/1261 [02:01<09:37,  1.82it/s]
# Radius of curvature: 39251.58 m
# Center offset: 0.06 m
#  17%|█▋        | 210/1261 [02:01<09:44,  1.80it/s]
# Radius of curvature: 5141.70 m
# Center offset: 0.07 m
#  17%|█▋        | 211/1261 [02:02<10:05,  1.73it/s]
# Radius of curvature: 3406.10 m
# Center offset: 0.07 m
#  17%|█▋        | 212/1261 [02:03<10:13,  1.71it/s]
# Radius of curvature: 1980.04 m
# Center offset: 0.09 m
#  17%|█▋        | 213/1261 [02:03<10:53,  1.60it/s]
# Radius of curvature: 1831.95 m
# Center offset: 0.09 m
#  17%|█▋        | 214/1261 [02:04<11:11,  1.56it/s]
# Radius of curvature: 2089.48 m
# Center offset: 0.10 m
#  17%|█▋        | 215/1261 [02:05<10:51,  1.61it/s]
# Radius of curvature: 1913.38 m
# Center offset: 0.10 m
#  17%|█▋        | 216/1261 [02:05<10:34,  1.65it/s]
# Radius of curvature: 1619.56 m
# Center offset: 0.11 m
#  17%|█▋        | 217/1261 [02:06<10:24,  1.67it/s]
# Radius of curvature: 1443.17 m
# Center offset: 0.12 m
#  17%|█▋        | 218/1261 [02:06<09:51,  1.76it/s]
# Radius of curvature: 1253.88 m
# Center offset: 0.12 m
#  17%|█▋        | 219/1261 [02:07<10:00,  1.73it/s]
# Radius of curvature: 1322.11 m
# Center offset: 0.12 m
#  17%|█▋        | 220/1261 [02:07<10:16,  1.69it/s]
# Radius of curvature: 1276.60 m
# Center offset: 0.13 m
#  18%|█▊        | 221/1261 [02:08<10:25,  1.66it/s]
# Radius of curvature: 9957.34 m
# Center offset: 0.10 m
#  18%|█▊        | 222/1261 [02:09<10:32,  1.64it/s]
# Radius of curvature: 1573.65 m
# Center offset: 0.11 m
#  18%|█▊        | 223/1261 [02:09<11:14,  1.54it/s]
# Radius of curvature: 2265.66 m
# Center offset: 0.11 m
#  18%|█▊        | 224/1261 [02:10<11:03,  1.56it/s]
# Radius of curvature: 5812.08 m
# Center offset: 0.10 m
#  18%|█▊        | 225/1261 [02:11<10:51,  1.59it/s]
# Radius of curvature: 4181.77 m
# Center offset: 0.11 m
#  18%|█▊        | 226/1261 [02:11<10:29,  1.64it/s]
# Radius of curvature: 3481.68 m
# Center offset: 0.12 m
#  18%|█▊        | 227/1261 [02:12<10:39,  1.62it/s]
# Radius of curvature: 11741.44 m
# Center offset: 0.13 m
#  18%|█▊        | 228/1261 [02:13<10:33,  1.63it/s]
# Radius of curvature: 5376.54 m
# Center offset: 0.14 m
#  18%|█▊        | 229/1261 [02:13<10:06,  1.70it/s]
# Radius of curvature: 4779.45 m
# Center offset: 0.15 m
#  18%|█▊        | 230/1261 [02:14<10:26,  1.65it/s]
# Radius of curvature: 2711.89 m
# Center offset: 0.16 m
#  18%|█▊        | 231/1261 [02:14<10:32,  1.63it/s]
# Radius of curvature: 2016.04 m
# Center offset: 0.17 m
#  18%|█▊        | 232/1261 [02:15<11:13,  1.53it/s]
# Radius of curvature: 3912.43 m
# Center offset: 0.15 m
#  18%|█▊        | 233/1261 [02:16<10:57,  1.56it/s]
# Radius of curvature: 4734.11 m
# Center offset: 0.15 m
#  19%|█▊        | 234/1261 [02:16<10:41,  1.60it/s]
# Radius of curvature: 8130.47 m
# Center offset: 0.16 m
#  19%|█▊        | 235/1261 [02:17<11:37,  1.47it/s]
# Radius of curvature: 2574.69 m
# Center offset: 0.18 m
#  19%|█▊        | 236/1261 [02:18<11:06,  1.54it/s]
# Radius of curvature: 1919.45 m
# Center offset: 0.20 m
#  19%|█▉        | 237/1261 [02:18<10:24,  1.64it/s]
# Radius of curvature: 2079.10 m
# Center offset: 0.20 m
#  19%|█▉        | 238/1261 [02:19<10:12,  1.67it/s]
# Radius of curvature: 2073.06 m
# Center offset: 0.21 m
#  19%|█▉        | 239/1261 [02:19<10:17,  1.65it/s]
# Radius of curvature: 2222.66 m
# Center offset: 0.20 m
#  19%|█▉        | 240/1261 [02:20<09:55,  1.71it/s]
# Radius of curvature: 2077.08 m
# Center offset: 0.21 m
#  19%|█▉        | 241/1261 [02:20<09:59,  1.70it/s]
# Radius of curvature: 2422.82 m
# Center offset: 0.21 m
#  19%|█▉        | 242/1261 [02:21<09:54,  1.71it/s]
# Radius of curvature: 2325.84 m
# Center offset: 0.21 m
#  19%|█▉        | 243/1261 [02:22<09:46,  1.74it/s]
# Radius of curvature: 1912.36 m
# Center offset: 0.22 m
#  19%|█▉        | 244/1261 [02:22<09:00,  1.88it/s]
# Radius of curvature: 1819.44 m
# Center offset: 0.23 m
#  19%|█▉        | 245/1261 [02:23<08:51,  1.91it/s]
# Radius of curvature: 1600.64 m
# Center offset: 0.23 m
#  20%|█▉        | 246/1261 [02:23<08:41,  1.95it/s]
# Radius of curvature: 1830.15 m
# Center offset: 0.22 m
#  20%|█▉        | 247/1261 [02:24<08:38,  1.96it/s]
# Radius of curvature: 1555.77 m
# Center offset: 0.23 m
#  20%|█▉        | 248/1261 [02:24<08:31,  1.98it/s]
# Radius of curvature: 1547.15 m
# Center offset: 0.24 m
#  20%|█▉        | 249/1261 [02:25<08:22,  2.01it/s]
# Radius of curvature: 12077.04 m
# Center offset: 0.21 m
#  20%|█▉        | 250/1261 [02:25<08:24,  2.00it/s]
# Radius of curvature: 1710.72 m
# Center offset: 0.23 m
#  20%|█▉        | 251/1261 [02:25<08:14,  2.04it/s]
# Radius of curvature: 1757.96 m
# Center offset: 0.23 m
#  20%|█▉        | 252/1261 [02:26<08:12,  2.05it/s]
# Radius of curvature: 1636.14 m
# Center offset: 0.24 m
#  20%|██        | 253/1261 [02:26<08:11,  2.05it/s]
# Radius of curvature: 1878.12 m
# Center offset: 0.23 m
#  20%|██        | 254/1261 [02:27<08:21,  2.01it/s]
# Radius of curvature: 1764.49 m
# Center offset: 0.23 m
#  20%|██        | 255/1261 [02:28<08:40,  1.93it/s]
# Radius of curvature: 1933.63 m
# Center offset: 0.23 m
#  20%|██        | 256/1261 [02:28<08:37,  1.94it/s]
# Radius of curvature: 1960.69 m
# Center offset: 0.22 m
#  20%|██        | 257/1261 [02:29<08:23,  2.00it/s]
# Radius of curvature: 2469.25 m
# Center offset: 0.21 m
#  20%|██        | 258/1261 [02:29<08:27,  1.98it/s]
# Radius of curvature: 2735.84 m
# Center offset: 0.21 m
#  21%|██        | 259/1261 [02:30<08:24,  1.98it/s]
# Radius of curvature: 15439.35 m
# Center offset: 0.20 m
#  21%|██        | 260/1261 [02:30<08:36,  1.94it/s]
# Radius of curvature: 2351.37 m
# Center offset: 0.21 m
#  21%|██        | 261/1261 [02:31<08:43,  1.91it/s]
# Radius of curvature: 1978.10 m
# Center offset: 0.22 m
#  21%|██        | 262/1261 [02:31<08:41,  1.92it/s]
# Radius of curvature: 2451.54 m
# Center offset: 0.21 m
#  21%|██        | 263/1261 [02:32<08:53,  1.87it/s]
# Radius of curvature: 2531.64 m
# Center offset: 0.21 m
#  21%|██        | 264/1261 [02:32<09:01,  1.84it/s]
# Radius of curvature: 2762.38 m
# Center offset: 0.21 m
#  21%|██        | 265/1261 [02:33<09:17,  1.79it/s]
# Radius of curvature: 2430.70 m
# Center offset: 0.21 m
#  21%|██        | 266/1261 [02:33<09:27,  1.75it/s]
# Radius of curvature: 2156.46 m
# Center offset: 0.21 m
#  21%|██        | 267/1261 [02:34<09:27,  1.75it/s]
# Radius of curvature: 1956.19 m
# Center offset: 0.22 m
#  21%|██▏       | 268/1261 [02:35<09:26,  1.75it/s]
# Radius of curvature: 2304.33 m
# Center offset: 0.21 m
#  21%|██▏       | 269/1261 [02:35<09:19,  1.77it/s]
# Radius of curvature: 2080.74 m
# Center offset: 0.21 m
#  21%|██▏       | 270/1261 [02:36<09:17,  1.78it/s]
# Radius of curvature: 2024.32 m
# Center offset: 0.20 m
#  21%|██▏       | 271/1261 [02:36<09:33,  1.73it/s]
# Radius of curvature: 1998.11 m
# Center offset: 0.20 m
#  22%|██▏       | 272/1261 [02:37<09:48,  1.68it/s]
# Radius of curvature: 2028.95 m
# Center offset: 0.20 m
#  22%|██▏       | 273/1261 [02:37<09:27,  1.74it/s]
# Radius of curvature: 2344.05 m
# Center offset: 0.19 m
#  22%|██▏       | 274/1261 [02:38<09:13,  1.78it/s]
# Radius of curvature: 2636.91 m
# Center offset: 0.18 m
#  22%|██▏       | 275/1261 [02:39<09:08,  1.80it/s]
# Radius of curvature: 3802.53 m
# Center offset: 0.18 m
#  22%|██▏       | 276/1261 [02:39<09:31,  1.72it/s]
# Radius of curvature: 3669.63 m
# Center offset: 0.18 m
#  22%|██▏       | 277/1261 [02:40<09:26,  1.74it/s]
# Radius of curvature: 3966.59 m
# Center offset: 0.18 m
#  22%|██▏       | 278/1261 [02:40<09:11,  1.78it/s]
# Radius of curvature: 2738.44 m
# Center offset: 0.18 m
#  22%|██▏       | 279/1261 [02:41<09:04,  1.80it/s]
# Radius of curvature: 2433.63 m
# Center offset: 0.18 m
#  22%|██▏       | 280/1261 [02:41<08:52,  1.84it/s]
# Radius of curvature: 2993.03 m
# Center offset: 0.16 m
#  22%|██▏       | 281/1261 [02:42<08:45,  1.86it/s]
# Radius of curvature: 2244.61 m
# Center offset: 0.17 m
#  22%|██▏       | 282/1261 [02:42<08:43,  1.87it/s]
# Radius of curvature: 2324.60 m
# Center offset: 0.16 m
#  22%|██▏       | 283/1261 [02:43<08:40,  1.88it/s]
# Radius of curvature: 2349.79 m
# Center offset: 0.15 m
#  23%|██▎       | 284/1261 [02:43<08:29,  1.92it/s]
# Radius of curvature: 2613.96 m
# Center offset: 0.15 m
#  23%|██▎       | 285/1261 [02:44<08:11,  1.98it/s]
# Radius of curvature: 3536.56 m
# Center offset: 0.13 m
#  23%|██▎       | 286/1261 [02:44<08:19,  1.95it/s]
# Radius of curvature: 3157.70 m
# Center offset: 0.14 m
#  23%|██▎       | 287/1261 [02:45<09:03,  1.79it/s]
# Radius of curvature: 2856.61 m
# Center offset: 0.14 m
#  23%|██▎       | 288/1261 [02:46<09:32,  1.70it/s]
# Radius of curvature: 2734.17 m
# Center offset: 0.13 m
#  23%|██▎       | 289/1261 [02:46<09:59,  1.62it/s]
# Radius of curvature: 3131.76 m
# Center offset: 0.13 m
#  23%|██▎       | 290/1261 [02:47<09:34,  1.69it/s]
# Radius of curvature: 2835.40 m
# Center offset: 0.13 m
#  23%|██▎       | 291/1261 [02:48<09:35,  1.69it/s]
# Radius of curvature: 3161.60 m
# Center offset: 0.12 m
#  23%|██▎       | 292/1261 [02:48<09:38,  1.67it/s]
# Radius of curvature: 3024.28 m
# Center offset: 0.12 m
#  23%|██▎       | 293/1261 [02:49<09:40,  1.67it/s]
# Radius of curvature: 7387.55 m
# Center offset: 0.10 m
#  23%|██▎       | 294/1261 [02:49<09:20,  1.72it/s]
# Radius of curvature: 3372.06 m
# Center offset: 0.11 m
#  23%|██▎       | 295/1261 [02:50<09:32,  1.69it/s]
# Radius of curvature: 3565.20 m
# Center offset: 0.11 m
#  23%|██▎       | 296/1261 [02:51<09:34,  1.68it/s]
# Radius of curvature: 3795.26 m
# Center offset: 0.11 m
#  24%|██▎       | 297/1261 [02:51<09:20,  1.72it/s]
# Radius of curvature: 5450.87 m
# Center offset: 0.10 m
#  24%|██▎       | 298/1261 [02:52<09:24,  1.71it/s]
# Radius of curvature: 3852.11 m
# Center offset: 0.11 m
#  24%|██▎       | 299/1261 [02:52<09:20,  1.72it/s]
# Radius of curvature: 3479.20 m
# Center offset: 0.11 m
#  24%|██▍       | 300/1261 [02:53<09:15,  1.73it/s]
# Radius of curvature: 3550.06 m
# Center offset: 0.11 m
#  24%|██▍       | 301/1261 [02:53<08:57,  1.79it/s]
# Radius of curvature: 3220.37 m
# Center offset: 0.11 m
#  24%|██▍       | 302/1261 [02:54<08:56,  1.79it/s]
# Radius of curvature: 9636.12 m
# Center offset: 0.11 m
#  24%|██▍       | 303/1261 [02:54<08:55,  1.79it/s]
# Radius of curvature: 3490.04 m
# Center offset: 0.12 m
#  24%|██▍       | 304/1261 [02:55<08:53,  1.79it/s]
# Radius of curvature: 2275.54 m
# Center offset: 0.16 m
#  24%|██▍       | 305/1261 [02:56<08:52,  1.79it/s]
# Radius of curvature: 3450.09 m
# Center offset: 0.11 m
#  24%|██▍       | 306/1261 [02:56<08:52,  1.79it/s]
# Radius of curvature: 4314.20 m
# Center offset: 0.09 m
#  24%|██▍       | 307/1261 [02:57<08:44,  1.82it/s]
# Radius of curvature: 4864.83 m
# Center offset: 0.09 m
#  24%|██▍       | 308/1261 [02:57<08:35,  1.85it/s]
# Radius of curvature: 6040.54 m
# Center offset: 0.09 m
#  25%|██▍       | 309/1261 [02:58<08:25,  1.88it/s]
# Radius of curvature: 8998.18 m
# Center offset: 0.07 m
#  25%|██▍       | 310/1261 [02:58<08:20,  1.90it/s]
# Radius of curvature: 5338.41 m
# Center offset: 0.09 m
#  25%|██▍       | 311/1261 [02:59<08:04,  1.96it/s]
# Radius of curvature: 6952.51 m
# Center offset: 0.09 m
#  25%|██▍       | 312/1261 [02:59<07:51,  2.01it/s]
# Radius of curvature: 33419.30 m
# Center offset: 0.09 m
#  25%|██▍       | 313/1261 [03:00<07:40,  2.06it/s]
# Radius of curvature: 16930.16 m
# Center offset: 0.09 m
#  25%|██▍       | 314/1261 [03:00<07:53,  2.00it/s]
# Radius of curvature: 6105.55 m
# Center offset: 0.09 m
#  25%|██▍       | 315/1261 [03:01<07:55,  1.99it/s]
# Radius of curvature: 12365.94 m
# Center offset: 0.09 m
#  25%|██▌       | 316/1261 [03:01<07:47,  2.02it/s]
# Radius of curvature: 6674.73 m
# Center offset: 0.11 m
#  25%|██▌       | 317/1261 [03:02<07:50,  2.00it/s]
# Radius of curvature: 6451.10 m
# Center offset: 0.05 m
#  25%|██▌       | 318/1261 [03:02<08:08,  1.93it/s]
# Radius of curvature: 7404.92 m
# Center offset: 0.08 m
#  25%|██▌       | 319/1261 [03:03<08:34,  1.83it/s]
# Radius of curvature: 8488.24 m
# Center offset: 0.08 m
#  25%|██▌       | 320/1261 [03:03<08:36,  1.82it/s]
# Radius of curvature: 16321.06 m
# Center offset: 0.08 m
#  25%|██▌       | 321/1261 [03:04<08:42,  1.80it/s]
# Radius of curvature: 91396.61 m
# Center offset: 0.09 m
#  26%|██▌       | 322/1261 [03:04<08:32,  1.83it/s]
# Radius of curvature: 28624.56 m
# Center offset: 0.10 m
#  26%|██▌       | 323/1261 [03:05<08:42,  1.80it/s]
# Radius of curvature: 11161.86 m
# Center offset: 0.09 m
#  26%|██▌       | 324/1261 [03:06<08:55,  1.75it/s]
# Radius of curvature: 12225.24 m
# Center offset: 0.09 m
#  26%|██▌       | 325/1261 [03:06<08:56,  1.74it/s]
# Radius of curvature: 9935.02 m
# Center offset: 0.09 m
#  26%|██▌       | 326/1261 [03:07<09:00,  1.73it/s]
# Radius of curvature: 255056.36 m
# Center offset: 0.09 m
#  26%|██▌       | 327/1261 [03:07<08:52,  1.75it/s]
# Radius of curvature: 9615.94 m
# Center offset: 0.10 m
#  26%|██▌       | 328/1261 [03:08<08:40,  1.79it/s]
# Radius of curvature: 10321.22 m
# Center offset: 0.12 m
#  26%|██▌       | 329/1261 [03:08<08:52,  1.75it/s]
# Radius of curvature: 13505.85 m
# Center offset: 0.08 m
#  26%|██▌       | 330/1261 [03:09<08:47,  1.76it/s]
# Radius of curvature: 9900.61 m
# Center offset: 0.08 m
#  26%|██▌       | 331/1261 [03:10<09:21,  1.66it/s]
# Radius of curvature: 15814.84 m
# Center offset: 0.08 m
#  26%|██▋       | 332/1261 [03:10<09:07,  1.70it/s]
# Radius of curvature: 173649.15 m
# Center offset: 0.08 m
#  26%|██▋       | 333/1261 [03:11<08:56,  1.73it/s]
# Radius of curvature: 15735.75 m
# Center offset: 0.09 m
#  26%|██▋       | 334/1261 [03:11<08:48,  1.76it/s]
# Radius of curvature: 11316.19 m
# Center offset: 0.09 m
#  27%|██▋       | 335/1261 [03:12<08:19,  1.85it/s]
# Radius of curvature: 10027.14 m
# Center offset: 0.09 m
#  27%|██▋       | 336/1261 [03:12<08:25,  1.83it/s]
# Radius of curvature: 19765.68 m
# Center offset: 0.09 m
#  27%|██▋       | 337/1261 [03:13<08:07,  1.90it/s]
# Radius of curvature: 130721.25 m
# Center offset: 0.09 m
#  27%|██▋       | 338/1261 [03:13<08:08,  1.89it/s]
# Radius of curvature: 53944.61 m
# Center offset: 0.08 m
#  27%|██▋       | 339/1261 [03:14<07:41,  2.00it/s]
# Radius of curvature: 18293.89 m
# Center offset: 0.09 m
#  27%|██▋       | 340/1261 [03:14<07:41,  2.00it/s]
# Radius of curvature: 9581.72 m
# Center offset: 0.09 m
#  27%|██▋       | 341/1261 [03:15<07:45,  1.97it/s]
# Radius of curvature: 8613.63 m
# Center offset: 0.10 m
#  27%|██▋       | 342/1261 [03:15<07:30,  2.04it/s]
# Radius of curvature: 16141.01 m
# Center offset: 0.09 m
#  27%|██▋       | 343/1261 [03:16<07:34,  2.02it/s]
# Radius of curvature: 34034.29 m
# Center offset: 0.06 m
#  27%|██▋       | 344/1261 [03:17<09:32,  1.60it/s]
# Radius of curvature: 82247.96 m
# Center offset: 0.07 m
#  27%|██▋       | 345/1261 [03:17<08:48,  1.73it/s]
# Radius of curvature: 12538.98 m
# Center offset: 0.09 m
#  27%|██▋       | 346/1261 [03:18<08:59,  1.70it/s]
# Radius of curvature: 58574.23 m
# Center offset: 0.07 m
#  28%|██▊       | 347/1261 [03:19<09:20,  1.63it/s]
# Radius of curvature: 11160.73 m
# Center offset: 0.07 m
#  28%|██▊       | 348/1261 [03:19<10:03,  1.51it/s]
# Radius of curvature: 6652.94 m
# Center offset: 0.08 m
#  28%|██▊       | 349/1261 [03:20<10:04,  1.51it/s]
# Radius of curvature: 5223.53 m
# Center offset: 0.08 m
#  28%|██▊       | 350/1261 [03:21<09:59,  1.52it/s]
# Radius of curvature: 13495.83 m
# Center offset: 0.08 m
#  28%|██▊       | 351/1261 [03:23<15:59,  1.05s/it]
# Radius of curvature: 19121.03 m
# Center offset: 0.08 m
#  28%|██▊       | 352/1261 [03:23<13:58,  1.08it/s]
# Radius of curvature: 12717.71 m
# Center offset: 0.08 m
#  28%|██▊       | 353/1261 [03:24<12:54,  1.17it/s]
# Radius of curvature: 5946.12 m
# Center offset: 0.13 m
#  28%|██▊       | 354/1261 [03:24<11:33,  1.31it/s]
# Radius of curvature: 350051.10 m
# Center offset: 0.07 m
#  28%|██▊       | 355/1261 [03:25<10:45,  1.40it/s]
# Radius of curvature: 18184.47 m
# Center offset: 0.08 m
#  28%|██▊       | 356/1261 [03:26<10:06,  1.49it/s]
# Radius of curvature: 50061.41 m
# Center offset: 0.09 m
#  28%|██▊       | 357/1261 [03:26<09:59,  1.51it/s]
# Radius of curvature: 4436.91 m
# Center offset: 0.11 m
#  28%|██▊       | 358/1261 [03:27<09:31,  1.58it/s]
# Radius of curvature: 6799.36 m
# Center offset: 0.09 m
#  28%|██▊       | 359/1261 [03:28<09:49,  1.53it/s]
# Radius of curvature: 5676.65 m
# Center offset: 0.09 m
#  29%|██▊       | 360/1261 [03:28<09:31,  1.58it/s]
# Radius of curvature: 4094.47 m
# Center offset: 0.09 m
#  29%|██▊       | 361/1261 [03:29<09:05,  1.65it/s]
# Radius of curvature: 5250.01 m
# Center offset: 0.09 m
#  29%|██▊       | 362/1261 [03:29<09:16,  1.62it/s]
# Radius of curvature: 17887.11 m
# Center offset: 0.08 m
#  29%|██▉       | 363/1261 [03:30<09:43,  1.54it/s]
# Radius of curvature: 4891.15 m
# Center offset: 0.08 m
#  29%|██▉       | 364/1261 [03:31<09:52,  1.51it/s]
# Radius of curvature: 14929.18 m
# Center offset: 0.04 m
#  29%|██▉       | 365/1261 [03:31<10:02,  1.49it/s]
# Radius of curvature: 26232.85 m
# Center offset: 0.06 m
#  29%|██▉       | 366/1261 [03:32<09:44,  1.53it/s]
# Radius of curvature: 6597.08 m
# Center offset: 0.06 m
#  29%|██▉       | 367/1261 [03:33<11:14,  1.33it/s]
# Radius of curvature: 6170.60 m
# Center offset: 0.05 m
#  29%|██▉       | 368/1261 [03:35<16:22,  1.10s/it]
# Radius of curvature: 4404.79 m
# Center offset: 0.06 m
#  29%|██▉       | 369/1261 [03:35<13:56,  1.07it/s]
# Radius of curvature: 3866.14 m
# Center offset: 0.06 m
#  29%|██▉       | 370/1261 [03:36<12:15,  1.21it/s]
# Radius of curvature: 5710.82 m
# Center offset: 0.06 m
#  29%|██▉       | 371/1261 [03:37<11:42,  1.27it/s]
# Radius of curvature: 4378.82 m
# Center offset: 0.07 m
#  30%|██▉       | 372/1261 [03:37<10:50,  1.37it/s]
# Radius of curvature: 5193.80 m
# Center offset: 0.07 m
#  30%|██▉       | 373/1261 [03:38<09:48,  1.51it/s]
# Radius of curvature: 5076.53 m
# Center offset: 0.08 m
#  30%|██▉       | 374/1261 [03:38<09:21,  1.58it/s]
# Radius of curvature: 3020.59 m
# Center offset: 0.09 m
#  30%|██▉       | 375/1261 [03:39<09:15,  1.59it/s]
# Radius of curvature: 6933.17 m
# Center offset: 0.10 m
#  30%|██▉       | 376/1261 [03:40<09:03,  1.63it/s]
# Radius of curvature: 3837.37 m
# Center offset: 0.08 m
#  30%|██▉       | 377/1261 [03:40<08:54,  1.66it/s]
# Radius of curvature: 6161.65 m
# Center offset: 0.09 m
#  30%|██▉       | 378/1261 [03:41<08:53,  1.66it/s]
# Radius of curvature: 29733.01 m
# Center offset: 0.10 m
#  30%|███       | 379/1261 [03:41<08:33,  1.72it/s]
# Radius of curvature: 16252.84 m
# Center offset: 0.10 m
#  30%|███       | 380/1261 [03:42<08:15,  1.78it/s]
# Radius of curvature: 82283.69 m
# Center offset: 0.10 m
#  30%|███       | 381/1261 [03:42<08:04,  1.82it/s]
# Radius of curvature: 16897.31 m
# Center offset: 0.12 m
#  30%|███       | 382/1261 [03:43<07:57,  1.84it/s]
# Radius of curvature: 18405.93 m
# Center offset: 0.11 m
#  30%|███       | 383/1261 [03:43<07:26,  1.97it/s]
# Radius of curvature: 11305.99 m
# Center offset: 0.11 m
#  30%|███       | 384/1261 [03:44<07:26,  1.97it/s]
# Radius of curvature: 8485.19 m
# Center offset: 0.11 m
#  31%|███       | 385/1261 [03:44<07:18,  2.00it/s]
# Radius of curvature: 8326.68 m
# Center offset: 0.11 m
#  31%|███       | 386/1261 [03:45<06:58,  2.09it/s]
# Radius of curvature: 7370.71 m
# Center offset: 0.11 m
#  31%|███       | 387/1261 [03:45<07:04,  2.06it/s]
# Radius of curvature: 7558.17 m
# Center offset: 0.11 m
#  31%|███       | 388/1261 [03:46<06:46,  2.15it/s]
# Radius of curvature: 25627.71 m
# Center offset: 0.11 m
#  31%|███       | 389/1261 [03:46<06:48,  2.14it/s]
# Radius of curvature: 6506.13 m
# Center offset: 0.09 m
#  31%|███       | 390/1261 [03:47<06:53,  2.11it/s]
# Radius of curvature: 11259.49 m
# Center offset: 0.10 m
#  31%|███       | 391/1261 [03:47<07:02,  2.06it/s]
# Radius of curvature: 15865.77 m
# Center offset: 0.11 m
#  31%|███       | 392/1261 [03:48<06:52,  2.11it/s]
# Radius of curvature: 93680.91 m
# Center offset: 0.09 m
#  31%|███       | 393/1261 [03:48<07:00,  2.07it/s]
# Radius of curvature: 16034.38 m
# Center offset: 0.12 m
#  31%|███       | 394/1261 [03:49<07:08,  2.03it/s]
# Radius of curvature: 33559.98 m
# Center offset: 0.10 m
#  31%|███▏      | 395/1261 [03:49<07:12,  2.00it/s]
# Radius of curvature: 10701.46 m
# Center offset: 0.11 m
#  31%|███▏      | 396/1261 [03:50<07:19,  1.97it/s]
# Radius of curvature: 12877.23 m
# Center offset: 0.11 m
#  31%|███▏      | 397/1261 [03:50<07:22,  1.95it/s]
# Radius of curvature: 105445.26 m
# Center offset: 0.12 m
#  32%|███▏      | 398/1261 [03:51<07:36,  1.89it/s]
# Radius of curvature: 23427.72 m
# Center offset: 0.12 m
#  32%|███▏      | 399/1261 [03:51<07:40,  1.87it/s]
# Radius of curvature: 12189.07 m
# Center offset: 0.12 m
#  32%|███▏      | 400/1261 [03:52<07:46,  1.85it/s]
# Radius of curvature: 45434.93 m
# Center offset: 0.13 m
#  32%|███▏      | 401/1261 [03:52<07:36,  1.88it/s]
# Radius of curvature: 4510.01 m
# Center offset: 0.11 m
#  32%|███▏      | 402/1261 [03:53<07:54,  1.81it/s]
# Radius of curvature: 5412.58 m
# Center offset: 0.11 m
#  32%|███▏      | 403/1261 [03:53<07:41,  1.86it/s]
# Radius of curvature: 77883.28 m
# Center offset: 0.13 m
#  32%|███▏      | 404/1261 [03:54<07:46,  1.84it/s]
# Radius of curvature: 5986.98 m
# Center offset: 0.12 m
#  32%|███▏      | 405/1261 [03:55<07:46,  1.83it/s]
# Radius of curvature: 12064.11 m
# Center offset: 0.14 m
#  32%|███▏      | 406/1261 [03:55<07:58,  1.79it/s]
# Radius of curvature: 12025.21 m
# Center offset: 0.14 m
#  32%|███▏      | 407/1261 [03:56<07:57,  1.79it/s]
# Radius of curvature: 67712.95 m
# Center offset: 0.14 m
#  32%|███▏      | 408/1261 [03:56<07:58,  1.78it/s]
# Radius of curvature: 53694.81 m
# Center offset: 0.14 m
#  32%|███▏      | 409/1261 [03:57<08:04,  1.76it/s]
# Radius of curvature: 430997.80 m
# Center offset: 0.15 m
#  33%|███▎      | 410/1261 [03:57<07:55,  1.79it/s]
# Radius of curvature: 12851.83 m
# Center offset: 0.15 m
#  33%|███▎      | 411/1261 [03:58<07:25,  1.91it/s]
# Radius of curvature: 9381.71 m
# Center offset: 0.15 m
#  33%|███▎      | 412/1261 [03:58<07:18,  1.94it/s]
# Radius of curvature: 23546.13 m
# Center offset: 0.16 m
#  33%|███▎      | 413/1261 [03:59<06:51,  2.06it/s]
# Radius of curvature: 6871.96 m
# Center offset: 0.15 m
#  33%|███▎      | 414/1261 [03:59<06:59,  2.02it/s]
# Radius of curvature: 11304.97 m
# Center offset: 0.16 m
#  33%|███▎      | 415/1261 [04:00<06:55,  2.03it/s]
# Radius of curvature: 19809.91 m
# Center offset: 0.18 m
#  33%|███▎      | 416/1261 [04:00<06:59,  2.02it/s]
# Radius of curvature: 137891.43 m
# Center offset: 0.17 m
#  33%|███▎      | 417/1261 [04:01<06:55,  2.03it/s]
# Radius of curvature: 23221.60 m
# Center offset: 0.17 m
#  33%|███▎      | 418/1261 [04:01<07:01,  2.00it/s]
# Radius of curvature: 11130.78 m
# Center offset: 0.17 m
#  33%|███▎      | 419/1261 [04:02<07:01,  2.00it/s]
# Radius of curvature: 13556.99 m
# Center offset: 0.18 m
#  33%|███▎      | 420/1261 [04:02<06:55,  2.02it/s]
# Radius of curvature: 11864.73 m
# Center offset: 0.19 m
#  33%|███▎      | 421/1261 [04:03<06:51,  2.04it/s]
# Radius of curvature: 8711.47 m
# Center offset: 0.19 m
#  33%|███▎      | 422/1261 [04:03<06:54,  2.03it/s]
# Radius of curvature: 5336.23 m
# Center offset: 0.19 m
#  34%|███▎      | 423/1261 [04:04<06:58,  2.00it/s]
# Radius of curvature: 7667.27 m
# Center offset: 0.19 m
#  34%|███▎      | 424/1261 [04:04<06:52,  2.03it/s]
# Radius of curvature: 6368.15 m
# Center offset: 0.20 m
#  34%|███▎      | 425/1261 [04:05<06:51,  2.03it/s]
# Radius of curvature: 4745.21 m
# Center offset: 0.18 m
#  34%|███▍      | 426/1261 [04:05<07:04,  1.97it/s]
# Radius of curvature: 96733.37 m
# Center offset: 0.20 m
#  34%|███▍      | 427/1261 [04:06<07:39,  1.81it/s]
# Radius of curvature: 7796.98 m
# Center offset: 0.20 m
#  34%|███▍      | 428/1261 [04:06<07:28,  1.86it/s]
# Radius of curvature: 9167.04 m
# Center offset: 0.21 m
#  34%|███▍      | 429/1261 [04:07<07:31,  1.84it/s]
# Radius of curvature: 8569.69 m
# Center offset: 0.21 m
#  34%|███▍      | 430/1261 [04:08<07:37,  1.82it/s]
# Radius of curvature: 9307.34 m
# Center offset: 0.21 m
#  34%|███▍      | 431/1261 [04:08<07:46,  1.78it/s]
# Radius of curvature: 20925.47 m
# Center offset: 0.22 m
#  34%|███▍      | 432/1261 [04:09<07:45,  1.78it/s]
# Radius of curvature: 21995.26 m
# Center offset: 0.22 m
#  34%|███▍      | 433/1261 [04:09<07:51,  1.76it/s]
# Radius of curvature: 17044.53 m
# Center offset: 0.22 m
#  34%|███▍      | 434/1261 [04:10<07:54,  1.74it/s]
# Radius of curvature: 14597.39 m
# Center offset: 0.22 m
#  34%|███▍      | 435/1261 [04:10<08:05,  1.70it/s]
# Radius of curvature: 367181.27 m
# Center offset: 0.23 m
#  35%|███▍      | 436/1261 [04:11<07:45,  1.77it/s]
# Radius of curvature: 18422.35 m
# Center offset: 0.25 m
#  35%|███▍      | 437/1261 [04:12<07:44,  1.77it/s]
# Radius of curvature: 22521.52 m
# Center offset: 0.23 m
#  35%|███▍      | 438/1261 [04:12<07:45,  1.77it/s]
# Radius of curvature: 249475.37 m
# Center offset: 0.24 m
#  35%|███▍      | 439/1261 [04:13<07:57,  1.72it/s]
# Radius of curvature: 26592.34 m
# Center offset: 0.22 m
#  35%|███▍      | 440/1261 [04:13<08:03,  1.70it/s]
# Radius of curvature: 24884.47 m
# Center offset: 0.22 m
#  35%|███▍      | 441/1261 [04:14<07:32,  1.81it/s]
# Radius of curvature: 11973.69 m
# Center offset: 0.22 m
#  35%|███▌      | 442/1261 [04:14<07:45,  1.76it/s]
# Radius of curvature: 9875.85 m
# Center offset: 0.23 m
#  35%|███▌      | 443/1261 [04:15<07:51,  1.74it/s]
# Radius of curvature: 6604.21 m
# Center offset: 0.24 m
#  35%|███▌      | 444/1261 [04:16<08:21,  1.63it/s]
# Radius of curvature: 5907.78 m
# Center offset: 0.24 m
#  35%|███▌      | 445/1261 [04:16<08:44,  1.56it/s]
# Radius of curvature: 6265.19 m
# Center offset: 0.24 m
#  35%|███▌      | 446/1261 [04:17<08:15,  1.65it/s]
# Radius of curvature: 4587.05 m
# Center offset: 0.24 m
#  35%|███▌      | 447/1261 [04:18<08:24,  1.61it/s]
# Radius of curvature: 17300.86 m
# Center offset: 0.25 m
#  36%|███▌      | 448/1261 [04:18<08:23,  1.62it/s]
# Radius of curvature: 4436.40 m
# Center offset: 0.22 m
#  36%|███▌      | 449/1261 [04:19<08:04,  1.67it/s]
# Radius of curvature: 13466.53 m
# Center offset: 0.24 m
#  36%|███▌      | 450/1261 [04:19<07:51,  1.72it/s]
# Radius of curvature: 13745.50 m
# Center offset: 0.25 m
#  36%|███▌      | 451/1261 [04:20<07:54,  1.71it/s]
# Radius of curvature: 14414.91 m
# Center offset: 0.26 m
#  36%|███▌      | 452/1261 [04:20<07:57,  1.70it/s]
# Radius of curvature: 15874.03 m
# Center offset: 0.25 m
#  36%|███▌      | 453/1261 [04:21<07:33,  1.78it/s]
# Radius of curvature: 9364.95 m
# Center offset: 0.24 m
#  36%|███▌      | 454/1261 [04:22<07:28,  1.80it/s]
# Radius of curvature: 39589.08 m
# Center offset: 0.25 m
#  36%|███▌      | 455/1261 [04:22<07:26,  1.81it/s]
# Radius of curvature: 9516.67 m
# Center offset: 0.26 m
#  36%|███▌      | 456/1261 [04:23<07:35,  1.77it/s]
# Radius of curvature: 9774.67 m
# Center offset: 0.25 m
#  36%|███▌      | 457/1261 [04:23<07:31,  1.78it/s]
# Radius of curvature: 12676.78 m
# Center offset: 0.25 m
#  36%|███▋      | 458/1261 [04:24<07:36,  1.76it/s]
# Radius of curvature: 12566.15 m
# Center offset: 0.24 m
#  36%|███▋      | 459/1261 [04:24<07:42,  1.73it/s]
# Radius of curvature: 13013.78 m
# Center offset: 0.25 m
#  36%|███▋      | 460/1261 [04:25<07:24,  1.80it/s]
# Radius of curvature: 18351.49 m
# Center offset: 0.25 m
#  37%|███▋      | 461/1261 [04:26<07:36,  1.75it/s]
# Radius of curvature: 7754.17 m
# Center offset: 0.25 m
# ...
# Radius of curvature: 3060.33 m
# Center offset: 0.02 m
#  88%|████████▊ | 1110/1261 [10:37<02:23,  1.05it/s]
# Radius of curvature: 2721.95 m
# Center offset: 0.02 m
#  88%|████████▊ | 1111/1261 [10:38<02:04,  1.20it/s]
# Radius of curvature: 2160.33 m
# Center offset: 0.02 m
#  88%|████████▊ | 1112/1261 [10:39<01:52,  1.32it/s]
# Radius of curvature: 1900.97 m
# Center offset: 0.02 m
#  88%|████████▊ | 1113/1261 [10:39<01:45,  1.41it/s]
# Radius of curvature: 1872.12 m
# Center offset: 0.03 m
#  88%|████████▊ | 1114/1261 [10:40<01:39,  1.48it/s]
# Radius of curvature: 2233.31 m
# Center offset: 0.04 m
#  88%|████████▊ | 1115/1261 [10:40<01:33,  1.57it/s]
# Radius of curvature: 2305.14 m
# Center offset: 0.05 m
#  89%|████████▊ | 1116/1261 [10:41<01:28,  1.64it/s]
# Radius of curvature: 2217.32 m
# Center offset: 0.05 m
#  89%|████████▊ | 1117/1261 [10:41<01:22,  1.74it/s]
# Radius of curvature: 1833.92 m
# Center offset: 0.01 m
#  89%|████████▊ | 1118/1261 [10:42<01:22,  1.73it/s]
# Radius of curvature: 2234.79 m
# Center offset: 0.04 m
#  89%|████████▊ | 1119/1261 [10:42<01:18,  1.80it/s]
# Radius of curvature: 3050.83 m
# Center offset: 0.04 m
#  89%|████████▉ | 1120/1261 [10:43<01:19,  1.78it/s]
# Radius of curvature: 5514.79 m
# Center offset: 0.07 m
#  89%|████████▉ | 1121/1261 [10:44<01:19,  1.76it/s]
# Radius of curvature: 7602.55 m
# Center offset: 0.07 m
#  89%|████████▉ | 1122/1261 [10:44<01:20,  1.72it/s]
# Radius of curvature: 17655.16 m
# Center offset: 0.07 m
#  89%|████████▉ | 1123/1261 [10:45<01:20,  1.71it/s]
# Radius of curvature: 15521.95 m
# Center offset: 0.07 m
#  89%|████████▉ | 1124/1261 [10:45<01:18,  1.74it/s]
# Radius of curvature: 7670.04 m
# Center offset: 0.08 m
#  89%|████████▉ | 1125/1261 [10:46<01:18,  1.73it/s]
# Radius of curvature: 4953.73 m
# Center offset: 0.08 m
#  89%|████████▉ | 1126/1261 [10:46<01:15,  1.80it/s]
# Radius of curvature: 4098.96 m
# Center offset: 0.09 m
#  89%|████████▉ | 1127/1261 [10:47<01:16,  1.75it/s]
# Radius of curvature: 3350.14 m
# Center offset: 0.08 m
#  89%|████████▉ | 1128/1261 [10:48<01:21,  1.64it/s]
# Radius of curvature: 2133.73 m
# Center offset: 0.06 m
#  90%|████████▉ | 1129/1261 [10:48<01:20,  1.63it/s]
# Radius of curvature: 1994.53 m
# Center offset: 0.06 m
#  90%|████████▉ | 1130/1261 [10:49<01:20,  1.63it/s]
# Radius of curvature: 1593.38 m
# Center offset: 0.04 m
#  90%|████████▉ | 1131/1261 [10:50<01:19,  1.64it/s]
# Radius of curvature: 1750.30 m
# Center offset: 0.07 m
#  90%|████████▉ | 1132/1261 [10:51<01:31,  1.42it/s]
# Radius of curvature: 1929.84 m
# Center offset: 0.08 m
#  90%|████████▉ | 1133/1261 [10:51<01:25,  1.50it/s]
# Radius of curvature: 1976.20 m
# Center offset: 0.09 m
#  90%|████████▉ | 1134/1261 [10:52<01:25,  1.48it/s]
# Radius of curvature: 1665.91 m
# Center offset: 0.09 m
#  90%|█████████ | 1135/1261 [10:52<01:25,  1.47it/s]
# Radius of curvature: 1686.61 m
# Center offset: 0.09 m
#  90%|█████████ | 1136/1261 [10:53<01:21,  1.54it/s]
# Radius of curvature: 1989.06 m
# Center offset: 0.10 m
#  90%|█████████ | 1137/1261 [10:54<01:28,  1.41it/s]
# Radius of curvature: 3352.86 m
# Center offset: 0.11 m
#  90%|█████████ | 1138/1261 [10:55<01:37,  1.26it/s]
# Radius of curvature: 3448.70 m
# Center offset: 0.11 m
#  90%|█████████ | 1139/1261 [10:56<01:30,  1.35it/s]
# Radius of curvature: 4169.86 m
# Center offset: 0.11 m
#  90%|█████████ | 1140/1261 [10:56<01:22,  1.47it/s]
# Radius of curvature: 2563.68 m
# Center offset: 0.08 m
#  90%|█████████ | 1141/1261 [10:57<01:17,  1.55it/s]
# Radius of curvature: 3369.03 m
# Center offset: 0.10 m
#  91%|█████████ | 1142/1261 [10:57<01:12,  1.64it/s]
# Radius of curvature: 5154.40 m
# Center offset: 0.10 m
#  91%|█████████ | 1143/1261 [10:58<01:08,  1.71it/s]
# Radius of curvature: 6441.95 m
# Center offset: 0.10 m
#  91%|█████████ | 1144/1261 [10:58<01:09,  1.68it/s]
# Radius of curvature: 5051.92 m
# Center offset: 0.09 m
#  91%|█████████ | 1145/1261 [10:59<01:10,  1.65it/s]
# Radius of curvature: 4938.41 m
# Center offset: 0.10 m
#  91%|█████████ | 1146/1261 [11:00<01:10,  1.64it/s]
# Radius of curvature: 4246.15 m
# Center offset: 0.09 m
#  91%|█████████ | 1147/1261 [11:00<01:08,  1.66it/s]
# Radius of curvature: 3722.78 m
# Center offset: 0.10 m
#  91%|█████████ | 1148/1261 [11:01<01:05,  1.73it/s]
# Radius of curvature: 3295.97 m
# Center offset: 0.09 m
#  91%|█████████ | 1149/1261 [11:01<01:05,  1.71it/s]
# Radius of curvature: 3567.05 m
# Center offset: 0.10 m
#  91%|█████████ | 1150/1261 [11:02<01:07,  1.64it/s]
# Radius of curvature: 5514.52 m
# Center offset: 0.10 m
#  91%|█████████▏| 1151/1261 [11:03<01:08,  1.61it/s]
# Radius of curvature: 1944.62 m
# Center offset: 0.06 m
#  91%|█████████▏| 1152/1261 [11:03<01:05,  1.65it/s]
# Radius of curvature: 1762.16 m
# Center offset: 0.06 m
#  91%|█████████▏| 1153/1261 [11:04<01:05,  1.64it/s]
# Radius of curvature: 2215.39 m
# Center offset: 0.09 m
#  92%|█████████▏| 1154/1261 [11:05<01:25,  1.25it/s]
# Radius of curvature: 1891.44 m
# Center offset: 0.08 m
#  92%|█████████▏| 1155/1261 [11:06<01:21,  1.31it/s]
# Radius of curvature: 2877.46 m
# Center offset: 0.11 m
#  92%|█████████▏| 1156/1261 [11:06<01:12,  1.44it/s]
# Radius of curvature: 2939.85 m
# Center offset: 0.11 m
#  92%|█████████▏| 1157/1261 [11:07<01:06,  1.56it/s]
# Radius of curvature: 2745.92 m
# Center offset: 0.11 m
#  92%|█████████▏| 1158/1261 [11:07<01:04,  1.59it/s]
# Radius of curvature: 2693.02 m
# Center offset: 0.11 m
#  92%|█████████▏| 1159/1261 [11:08<01:04,  1.59it/s]
# Radius of curvature: 2639.76 m
# Center offset: 0.11 m
#  92%|█████████▏| 1160/1261 [11:09<01:04,  1.57it/s]
# Radius of curvature: 2730.56 m
# Center offset: 0.12 m
#  92%|█████████▏| 1161/1261 [11:09<01:04,  1.55it/s]
# Radius of curvature: 2563.12 m
# Center offset: 0.12 m
#  92%|█████████▏| 1162/1261 [11:11<01:29,  1.10it/s]
# Radius of curvature: 2695.39 m
# Center offset: 0.12 m
#  92%|█████████▏| 1163/1261 [11:11<01:17,  1.26it/s]
# Radius of curvature: 1422.23 m
# Center offset: 0.08 m
#  92%|█████████▏| 1164/1261 [11:12<01:08,  1.41it/s]
# Radius of curvature: 1497.42 m
# Center offset: 0.10 m
#  92%|█████████▏| 1165/1261 [11:12<01:02,  1.53it/s]
# Radius of curvature: 1485.67 m
# Center offset: 0.11 m
#  92%|█████████▏| 1166/1261 [11:13<01:00,  1.58it/s]
# Radius of curvature: 1550.82 m
# Center offset: 0.11 m
#  93%|█████████▎| 1167/1261 [11:14<00:57,  1.65it/s]
# Radius of curvature: 1734.52 m
# Center offset: 0.13 m
#  93%|█████████▎| 1168/1261 [11:14<00:54,  1.72it/s]
# Radius of curvature: 1507.28 m
# Center offset: 0.12 m
#  93%|█████████▎| 1169/1261 [11:15<00:53,  1.73it/s]
# Radius of curvature: 1555.34 m
# Center offset: 0.13 m
#  93%|█████████▎| 1170/1261 [11:15<00:55,  1.63it/s]
# Radius of curvature: 2013.39 m
# Center offset: 0.14 m
#  93%|█████████▎| 1171/1261 [11:16<00:53,  1.69it/s]
# Radius of curvature: 1972.84 m
# Center offset: 0.14 m
#  93%|█████████▎| 1172/1261 [11:16<00:52,  1.68it/s]
# Radius of curvature: 2417.49 m
# Center offset: 0.15 m
#  93%|█████████▎| 1173/1261 [11:17<00:52,  1.67it/s]
# Radius of curvature: 2239.27 m
# Center offset: 0.14 m
#  93%|█████████▎| 1174/1261 [11:18<00:53,  1.64it/s]
# Radius of curvature: 2722.94 m
# Center offset: 0.12 m
#  93%|█████████▎| 1175/1261 [11:18<00:52,  1.65it/s]
# Radius of curvature: 2741.66 m
# Center offset: 0.11 m
#  93%|█████████▎| 1176/1261 [11:19<00:53,  1.60it/s]
# Radius of curvature: 3249.73 m
# Center offset: 0.12 m
#  93%|█████████▎| 1177/1261 [11:20<00:53,  1.57it/s]
# Radius of curvature: 3189.25 m
# Center offset: 0.11 m
#  93%|█████████▎| 1178/1261 [11:20<00:51,  1.61it/s]
# Radius of curvature: 3388.79 m
# Center offset: 0.12 m
#  93%|█████████▎| 1179/1261 [11:21<00:48,  1.70it/s]
# Radius of curvature: 3436.47 m
# Center offset: 0.11 m
#  94%|█████████▎| 1180/1261 [11:22<00:57,  1.40it/s]
# Radius of curvature: 4183.44 m
# Center offset: 0.11 m
#  94%|█████████▎| 1181/1261 [11:22<00:55,  1.45it/s]
# Radius of curvature: 4014.72 m
# Center offset: 0.10 m
#  94%|█████████▎| 1182/1261 [11:24<01:08,  1.15it/s]
# Radius of curvature: 4764.00 m
# Center offset: 0.09 m
#  94%|█████████▍| 1183/1261 [11:24<01:01,  1.27it/s]
# Radius of curvature: 19809.76 m
# Center offset: 0.09 m
#  94%|█████████▍| 1184/1261 [11:25<00:57,  1.34it/s]
# Radius of curvature: 4055.42 m
# Center offset: 0.07 m
#  94%|█████████▍| 1185/1261 [11:25<00:53,  1.42it/s]
# Radius of curvature: 3092.33 m
# Center offset: 0.00 m
#  94%|█████████▍| 1186/1261 [11:26<00:51,  1.47it/s]
# Radius of curvature: 2998.56 m
# Center offset: 0.03 m
#  94%|█████████▍| 1187/1261 [11:27<00:50,  1.47it/s]
# Radius of curvature: 2783.13 m
# Center offset: 0.02 m
#  94%|█████████▍| 1188/1261 [11:27<00:48,  1.50it/s]
# Radius of curvature: 2922.95 m
# Center offset: 0.02 m
#  94%|█████████▍| 1189/1261 [11:28<00:45,  1.58it/s]
# Radius of curvature: 2838.78 m
# Center offset: 0.01 m
#  94%|█████████▍| 1190/1261 [11:29<00:44,  1.59it/s]
# Radius of curvature: 2491.03 m
# Center offset: 0.02 m
#  94%|█████████▍| 1191/1261 [11:29<00:43,  1.59it/s]
# Radius of curvature: 2134.59 m
# Center offset: 0.03 m
#  95%|█████████▍| 1192/1261 [11:30<00:42,  1.61it/s]
# Radius of curvature: 1993.19 m
# Center offset: 0.03 m
#  95%|█████████▍| 1193/1261 [11:30<00:41,  1.64it/s]
# Radius of curvature: 1722.64 m
# Center offset: 0.03 m
#  95%|█████████▍| 1194/1261 [11:31<00:39,  1.69it/s]
# Radius of curvature: 1954.38 m
# Center offset: 0.04 m
#  95%|█████████▍| 1195/1261 [11:32<00:38,  1.70it/s]
# Radius of curvature: 1761.53 m
# Center offset: 0.04 m
#  95%|█████████▍| 1196/1261 [11:32<00:37,  1.76it/s]
# Radius of curvature: 2541.67 m
# Center offset: 0.04 m
#  95%|█████████▍| 1197/1261 [11:33<00:37,  1.73it/s]
# Radius of curvature: 1411.55 m
# Center offset: 0.00 m
#  95%|█████████▌| 1198/1261 [11:33<00:36,  1.71it/s]
# Radius of curvature: 1648.56 m
# Center offset: 0.02 m
#  95%|█████████▌| 1199/1261 [11:34<00:36,  1.68it/s]
# Radius of curvature: 2098.21 m
# Center offset: 0.02 m
#  95%|█████████▌| 1200/1261 [11:35<00:37,  1.65it/s]
# Radius of curvature: 2868.44 m
# Center offset: 0.03 m
#  95%|█████████▌| 1201/1261 [11:35<00:36,  1.64it/s]
# Radius of curvature: 4836.26 m
# Center offset: 0.04 m
#  95%|█████████▌| 1202/1261 [11:36<00:34,  1.71it/s]
# Radius of curvature: 2946.24 m
# Center offset: 0.02 m
#  95%|█████████▌| 1203/1261 [11:36<00:33,  1.72it/s]
# Radius of curvature: 2948.34 m
# Center offset: 0.01 m
#  95%|█████████▌| 1204/1261 [11:37<00:32,  1.74it/s]
# Radius of curvature: 2868.36 m
# Center offset: 0.01 m
#  96%|█████████▌| 1205/1261 [11:37<00:33,  1.69it/s]
# Radius of curvature: 2573.18 m
# Center offset: 0.00 m
#  96%|█████████▌| 1206/1261 [11:38<00:32,  1.68it/s]
# Radius of curvature: 1869.46 m
# Center offset: 0.00 m
#  96%|█████████▌| 1207/1261 [11:39<00:31,  1.74it/s]
# Radius of curvature: 1860.50 m
# Center offset: 0.02 m
#  96%|█████████▌| 1208/1261 [11:39<00:30,  1.75it/s]
# Radius of curvature: 1406.84 m
# Center offset: 0.05 m
#  96%|█████████▌| 1209/1261 [11:40<00:30,  1.72it/s]
# Radius of curvature: 1741.54 m
# Center offset: 0.01 m
#  96%|█████████▌| 1210/1261 [11:41<00:40,  1.27it/s]
# Radius of curvature: 1540.42 m
# Center offset: 0.02 m
#  96%|█████████▌| 1211/1261 [11:42<00:37,  1.32it/s]
# Radius of curvature: 1661.37 m
# Center offset: 0.00 m
#  96%|█████████▌| 1212/1261 [11:42<00:33,  1.44it/s]
# Radius of curvature: 3354.35 m
# Center offset: 0.02 m
#  96%|█████████▌| 1213/1261 [11:43<00:31,  1.54it/s]
# Radius of curvature: 1855.83 m
# Center offset: 0.01 m
#  96%|█████████▋| 1214/1261 [11:43<00:30,  1.57it/s]
# Radius of curvature: 1789.33 m
# Center offset: 0.00 m
#  96%|█████████▋| 1215/1261 [11:44<00:28,  1.59it/s]
# Radius of curvature: 1968.71 m
# Center offset: 0.00 m
#  96%|█████████▋| 1216/1261 [11:45<00:27,  1.61it/s]
# Radius of curvature: 2171.82 m
# Center offset: 0.00 m
#  97%|█████████▋| 1217/1261 [11:45<00:27,  1.60it/s]
# Radius of curvature: 2708.60 m
# Center offset: 0.01 m
#  97%|█████████▋| 1218/1261 [11:46<00:26,  1.59it/s]
# Radius of curvature: 2273.75 m
# Center offset: 0.00 m
#  97%|█████████▋| 1219/1261 [11:46<00:26,  1.62it/s]
# Radius of curvature: 1680.88 m
# Center offset: 0.06 m
#  97%|█████████▋| 1220/1261 [11:47<00:24,  1.70it/s]
# Radius of curvature: 1801.40 m
# Center offset: 0.05 m
#  97%|█████████▋| 1221/1261 [11:48<00:23,  1.72it/s]
# Radius of curvature: 2403.39 m
# Center offset: 0.03 m
#  97%|█████████▋| 1222/1261 [11:48<00:22,  1.72it/s]
# Radius of curvature: 2478.35 m
# Center offset: 0.02 m
#  97%|█████████▋| 1223/1261 [11:49<00:22,  1.69it/s]
# Radius of curvature: 40292.19 m
# Center offset: 0.01 m
#  97%|█████████▋| 1224/1261 [11:49<00:21,  1.75it/s]
# Radius of curvature: 2692.48 m
# Center offset: 0.03 m
#  97%|█████████▋| 1225/1261 [11:50<00:21,  1.68it/s]
# Radius of curvature: 2878.84 m
# Center offset: 0.03 m
#  97%|█████████▋| 1226/1261 [11:50<00:20,  1.74it/s]
# Radius of curvature: 3177.29 m
# Center offset: 0.03 m
#  97%|█████████▋| 1227/1261 [11:51<00:19,  1.75it/s]
# Radius of curvature: 2847.03 m
# Center offset: 0.04 m
#  97%|█████████▋| 1228/1261 [11:52<00:18,  1.75it/s]
# Radius of curvature: 3823.46 m
# Center offset: 0.03 m
#  97%|█████████▋| 1229/1261 [11:52<00:18,  1.74it/s]
# Radius of curvature: 3636.48 m
# Center offset: 0.04 m
#  98%|█████████▊| 1230/1261 [11:53<00:17,  1.73it/s]
# Radius of curvature: 2754.04 m
# Center offset: 0.11 m
#  98%|█████████▊| 1231/1261 [11:53<00:17,  1.68it/s]
# Radius of curvature: 2550.10 m
# Center offset: 0.10 m
#  98%|█████████▊| 1232/1261 [11:54<00:17,  1.69it/s]
# Radius of curvature: 2498.87 m
# Center offset: 0.08 m
#  98%|█████████▊| 1233/1261 [11:54<00:15,  1.76it/s]
# Radius of curvature: 2377.69 m
# Center offset: 0.06 m
#  98%|█████████▊| 1234/1261 [11:55<00:15,  1.76it/s]
# Radius of curvature: 10669.51 m
# Center offset: 0.03 m
#  98%|█████████▊| 1235/1261 [11:56<00:15,  1.69it/s]
# Radius of curvature: 2941.84 m
# Center offset: 0.05 m
#  98%|█████████▊| 1236/1261 [11:56<00:15,  1.64it/s]
# Radius of curvature: 3192.54 m
# Center offset: 0.06 m
#  98%|█████████▊| 1237/1261 [11:57<00:15,  1.59it/s]
# Radius of curvature: 4419.59 m
# Center offset: 0.06 m
#  98%|█████████▊| 1238/1261 [11:58<00:17,  1.32it/s]
# Radius of curvature: 4992.15 m
# Center offset: 0.06 m
#  98%|█████████▊| 1239/1261 [11:59<00:15,  1.41it/s]
# Radius of curvature: 15332.76 m
# Center offset: 0.05 m
#  98%|█████████▊| 1240/1261 [11:59<00:13,  1.59it/s]
# Radius of curvature: 57129.83 m
# Center offset: 0.06 m
#  98%|█████████▊| 1241/1261 [12:00<00:11,  1.67it/s]
# Radius of curvature: 57529.74 m
# Center offset: 0.12 m
#  98%|█████████▊| 1242/1261 [12:00<00:11,  1.68it/s]
# Radius of curvature: 13146.63 m
# Center offset: 0.12 m
#  99%|█████████▊| 1243/1261 [12:01<00:10,  1.76it/s]
# Radius of curvature: 48490.88 m
# Center offset: 0.12 m
#  99%|█████████▊| 1244/1261 [12:01<00:09,  1.77it/s]
# Radius of curvature: 20770.80 m
# Center offset: 0.10 m
#  99%|█████████▊| 1245/1261 [12:02<00:09,  1.73it/s]
# Radius of curvature: 10869.27 m
# Center offset: 0.10 m
#  99%|█████████▉| 1246/1261 [12:03<00:08,  1.67it/s]
# Radius of curvature: 6576.92 m
# Center offset: 0.11 m
#  99%|█████████▉| 1247/1261 [12:03<00:08,  1.72it/s]
# Radius of curvature: 5404.71 m
# Center offset: 0.11 m
#  99%|█████████▉| 1248/1261 [12:04<00:07,  1.72it/s]
# Radius of curvature: 6785.18 m
# Center offset: 0.11 m
#  99%|█████████▉| 1249/1261 [12:04<00:07,  1.70it/s]
# Radius of curvature: 12672.69 m
# Center offset: 0.10 m
#  99%|█████████▉| 1250/1261 [12:05<00:06,  1.69it/s]
# Radius of curvature: 11572.33 m
# Center offset: 0.10 m
#  99%|█████████▉| 1251/1261 [12:06<00:06,  1.66it/s]
# Radius of curvature: 9859.04 m
# Center offset: 0.10 m
#  99%|█████████▉| 1252/1261 [12:06<00:05,  1.64it/s]
# Radius of curvature: 8780.00 m
# Center offset: 0.10 m
#  99%|█████████▉| 1253/1261 [12:07<00:04,  1.66it/s]
# Radius of curvature: 8912.98 m
# Center offset: 0.11 m
#  99%|█████████▉| 1254/1261 [12:07<00:04,  1.60it/s]
# Radius of curvature: 9631.25 m
# Center offset: 0.12 m
# 100%|█████████▉| 1255/1261 [12:08<00:03,  1.52it/s]
# Radius of curvature: 12486.00 m
# Center offset: 0.10 m
# 100%|█████████▉| 1256/1261 [12:09<00:03,  1.49it/s]
# Radius of curvature: 9580.08 m
# Center offset: 0.07 m
# 100%|█████████▉| 1257/1261 [12:10<00:03,  1.09it/s]
# Radius of curvature: 12550.86 m
# Center offset: 0.07 m
# 100%|█████████▉| 1258/1261 [12:11<00:02,  1.02it/s]
# Radius of curvature: 27392.56 m
# Center offset: 0.07 m
# 100%|█████████▉| 1259/1261 [12:12<00:01,  1.12it/s]
# Radius of curvature: 12608.57 m
# Center offset: 0.07 m
# 100%|█████████▉| 1260/1261 [12:13<00:00,  1.22it/s]
# [MoviePy] Done.
# [MoviePy] >>>> Video ready: project_output.mp4
#
# Wall time: 12min 17s

# %%
white_output = 'test_videos_output/solidWhiteRight.mp4'

#white_clip = clip1.fl_image(process_image) #NOTE: this function expects color images!!
#%time white_clip.write_videofile(white_output, audio=False)
